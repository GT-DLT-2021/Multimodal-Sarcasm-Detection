# %%
# !pip install pytorch_lightning #torch==1.3.1
# !pip install transformers
# !pip3 -q install emoji
# Out:
# Requirement already satisfied: pytorch_lightning in /Users/albert/opt/anaconda3/envs/DLT_project2/lib/python3.8/site-packages (1.5.3)
# Requirement already satisfied: torchmetrics>=0.4.1 in /Users/albert/opt/anaconda3/envs/DLT_project2/lib/python3.8/site-packages (from pytorch_lightning) (0.6.0)
# Requirement already satisfied: pyDeprecate==0.3.1 in /Users/albert/opt/anaconda3/envs/DLT_project2/lib/python3.8/site-packages (from pytorch_lightning) (0.3.1)
# Requirement already satisfied: tensorboard>=2.2.0 in /Users/albert/opt/anaconda3/envs/DLT_project2/lib/python3.8/site-packages (from pytorch_lightning) (2.7.0)
# Requirement already satisfied: fsspec[http]!=2021.06.0,>=2021.05.0 in /Users/albert/opt/anaconda3/envs/DLT_project2/lib/python3.8/site-packages (from pytorch_lightning) (2021.11.0)
# Requirement already satisfied: PyYAML>=5.1 in /Users/albert/opt/anaconda3/envs/DLT_project2/lib/python3.8/site-packages (from pytorch_lightning) (6.0)
# Requirement already satisfied: packaging>=17.0 in /Users/albert/opt/anaconda3/envs/DLT_project2/lib/python3.8/site-packages (from pytorch_lightning) (21.0)
# Requirement already satisfied: torch>=1.6 in /Users/albert/opt/anaconda3/envs/DLT_project2/lib/python3.8/site-packages (from pytorch_lightning) (1.10.0)
# Requirement already satisfied: future>=0.17.1 in /Users/albert/opt/anaconda3/envs/DLT_project2/lib/python3.8/site-packages (from pytorch_lightning) (0.18.2)
# Requirement already satisfied: numpy>=1.17.2 in /Users/albert/opt/anaconda3/envs/DLT_project2/lib/python3.8/site-packages (from pytorch_lightning) (1.21.2)
# Requirement already satisfied: tqdm>=4.41.0 in /Users/albert/opt/anaconda3/envs/DLT_project2/lib/python3.8/site-packages (from pytorch_lightning) (4.62.3)
# Requirement already satisfied: typing-extensions in /Users/albert/opt/anaconda3/envs/DLT_project2/lib/python3.8/site-packages (from pytorch_lightning) (3.10.0.2)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /Users/albert/opt/anaconda3/envs/DLT_project2/lib/python3.8/site-packages (from tensorboard>=2.2.0->pytorch_lightning) (0.4.6)
# Requirement already satisfied: protobuf>=3.6.0 in /Users/albert/opt/anaconda3/envs/DLT_project2/lib/python3.8/site-packages (from tensorboard>=2.2.0->pytorch_lightning) (3.19.1)
# Requirement already satisfied: grpcio>=1.24.3 in /Users/albert/opt/anaconda3/envs/DLT_project2/lib/python3.8/site-packages (from tensorboard>=2.2.0->pytorch_lightning) (1.41.1)
# Requirement already satisfied: setuptools>=41.0.0 in /Users/albert/opt/anaconda3/envs/DLT_project2/lib/python3.8/site-packages (from tensorboard>=2.2.0->pytorch_lightning) (58.0.4)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /Users/albert/opt/anaconda3/envs/DLT_project2/lib/python3.8/site-packages (from tensorboard>=2.2.0->pytorch_lightning) (0.6.1)
# Requirement already satisfied: werkzeug>=0.11.15 in /Users/albert/opt/anaconda3/envs/DLT_project2/lib/python3.8/site-packages (from tensorboard>=2.2.0->pytorch_lightning) (2.0.2)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /Users/albert/opt/anaconda3/envs/DLT_project2/lib/python3.8/site-packages (from tensorboard>=2.2.0->pytorch_lightning) (1.8.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /Users/albert/opt/anaconda3/envs/DLT_project2/lib/python3.8/site-packages (from tensorboard>=2.2.0->pytorch_lightning) (2.3.3)
# Requirement already satisfied: markdown>=2.6.8 in /Users/albert/opt/anaconda3/envs/DLT_project2/lib/python3.8/site-packages (from tensorboard>=2.2.0->pytorch_lightning) (3.3.4)
# Requirement already satisfied: absl-py>=0.4 in /Users/albert/opt/anaconda3/envs/DLT_project2/lib/python3.8/site-packages (from tensorboard>=2.2.0->pytorch_lightning) (1.0.0)
# Requirement already satisfied: requests<3,>=2.21.0 in /Users/albert/opt/anaconda3/envs/DLT_project2/lib/python3.8/site-packages (from tensorboard>=2.2.0->pytorch_lightning) (2.26.0)
# Requirement already satisfied: wheel>=0.26 in /Users/albert/opt/anaconda3/envs/DLT_project2/lib/python3.8/site-packages (from tensorboard>=2.2.0->pytorch_lightning) (0.37.0)
# Requirement already satisfied: aiohttp; extra == "http" in /Users/albert/opt/anaconda3/envs/DLT_project2/lib/python3.8/site-packages (from fsspec[http]!=2021.06.0,>=2021.05.0->pytorch_lightning) (3.7.4.post0)
# Requirement already satisfied: pyparsing>=2.0.2 in /Users/albert/opt/anaconda3/envs/DLT_project2/lib/python3.8/site-packages (from packaging>=17.0->pytorch_lightning) (3.0.6)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /Users/albert/opt/anaconda3/envs/DLT_project2/lib/python3.8/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.2.0->pytorch_lightning) (1.3.0)
# Requirement already satisfied: six>=1.5.2 in /Users/albert/opt/anaconda3/envs/DLT_project2/lib/python3.8/site-packages (from grpcio>=1.24.3->tensorboard>=2.2.0->pytorch_lightning) (1.16.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/albert/opt/anaconda3/envs/DLT_project2/lib/python3.8/site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch_lightning) (0.2.7)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /Users/albert/opt/anaconda3/envs/DLT_project2/lib/python3.8/site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch_lightning) (4.2.4)
# Requirement already satisfied: rsa<5,>=3.1.4; python_version >= "3.6" in /Users/albert/opt/anaconda3/envs/DLT_project2/lib/python3.8/site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch_lightning) (4.7.2)
# Requirement already satisfied: charset-normalizer~=2.0.0; python_version >= "3" in /Users/albert/opt/anaconda3/envs/DLT_project2/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard>=2.2.0->pytorch_lightning) (2.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/albert/opt/anaconda3/envs/DLT_project2/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard>=2.2.0->pytorch_lightning) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5; python_version >= "3" in /Users/albert/opt/anaconda3/envs/DLT_project2/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard>=2.2.0->pytorch_lightning) (3.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/albert/opt/anaconda3/envs/DLT_project2/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard>=2.2.0->pytorch_lightning) (1.26.7)
# Requirement already satisfied: yarl<2.0,>=1.0 in /Users/albert/opt/anaconda3/envs/DLT_project2/lib/python3.8/site-packages (from aiohttp; extra == "http"->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch_lightning) (1.7.2)
# Requirement already satisfied: chardet<5.0,>=2.0 in /Users/albert/opt/anaconda3/envs/DLT_project2/lib/python3.8/site-packages (from aiohttp; extra == "http"->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch_lightning) (4.0.0)
# Requirement already satisfied: attrs>=17.3.0 in /Users/albert/opt/anaconda3/envs/DLT_project2/lib/python3.8/site-packages (from aiohttp; extra == "http"->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch_lightning) (21.2.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/albert/opt/anaconda3/envs/DLT_project2/lib/python3.8/site-packages (from aiohttp; extra == "http"->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch_lightning) (5.2.0)
# Requirement already satisfied: async-timeout<4.0,>=3.0 in /Users/albert/opt/anaconda3/envs/DLT_project2/lib/python3.8/site-packages (from aiohttp; extra == "http"->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch_lightning) (3.0.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /Users/albert/opt/anaconda3/envs/DLT_project2/lib/python3.8/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.2.0->pytorch_lightning) (3.1.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /Users/albert/opt/anaconda3/envs/DLT_project2/lib/python3.8/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch_lightning) (0.4.8)
# Requirement already satisfied: transformers in /Users/albert/opt/anaconda3/envs/DLT_project2/lib/python3.8/site-packages (4.12.3)
# Requirement already satisfied: filelock in /Users/albert/opt/anaconda3/envs/DLT_project2/lib/python3.8/site-packages (from transformers) (3.4.0)
# Requirement already satisfied: pyyaml>=5.1 in /Users/albert/opt/anaconda3/envs/DLT_project2/lib/python3.8/site-packages (from transformers) (6.0)
# Requirement already satisfied: tokenizers<0.11,>=0.10.1 in /Users/albert/opt/anaconda3/envs/DLT_project2/lib/python3.8/site-packages (from transformers) (0.10.3)
# Requirement already satisfied: numpy>=1.17 in /Users/albert/opt/anaconda3/envs/DLT_project2/lib/python3.8/site-packages (from transformers) (1.21.2)
# Requirement already satisfied: sacremoses in /Users/albert/opt/anaconda3/envs/DLT_project2/lib/python3.8/site-packages (from transformers) (0.0.46)
# Requirement already satisfied: packaging>=20.0 in /Users/albert/opt/anaconda3/envs/DLT_project2/lib/python3.8/site-packages (from transformers) (21.0)
# Requirement already satisfied: tqdm>=4.27 in /Users/albert/opt/anaconda3/envs/DLT_project2/lib/python3.8/site-packages (from transformers) (4.62.3)
# Requirement already satisfied: huggingface-hub<1.0,>=0.1.0 in /Users/albert/opt/anaconda3/envs/DLT_project2/lib/python3.8/site-packages (from transformers) (0.1.2)
# Requirement already satisfied: requests in /Users/albert/opt/anaconda3/envs/DLT_project2/lib/python3.8/site-packages (from transformers) (2.26.0)
# Requirement already satisfied: regex!=2019.12.17 in /Users/albert/opt/anaconda3/envs/DLT_project2/lib/python3.8/site-packages (from transformers) (2021.11.10)
# Requirement already satisfied: joblib in /Users/albert/opt/anaconda3/envs/DLT_project2/lib/python3.8/site-packages (from sacremoses->transformers) (1.1.0)
# Requirement already satisfied: click in /Users/albert/opt/anaconda3/envs/DLT_project2/lib/python3.8/site-packages (from sacremoses->transformers) (8.0.3)
# Requirement already satisfied: six in /Users/albert/opt/anaconda3/envs/DLT_project2/lib/python3.8/site-packages (from sacremoses->transformers) (1.16.0)
# Requirement already satisfied: pyparsing>=2.0.2 in /Users/albert/opt/anaconda3/envs/DLT_project2/lib/python3.8/site-packages (from packaging>=20.0->transformers) (3.0.6)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/albert/opt/anaconda3/envs/DLT_project2/lib/python3.8/site-packages (from huggingface-hub<1.0,>=0.1.0->transformers) (3.10.0.2)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/albert/opt/anaconda3/envs/DLT_project2/lib/python3.8/site-packages (from requests->transformers) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/albert/opt/anaconda3/envs/DLT_project2/lib/python3.8/site-packages (from requests->transformers) (1.26.7)
# Requirement already satisfied: idna<4,>=2.5; python_version >= "3" in /Users/albert/opt/anaconda3/envs/DLT_project2/lib/python3.8/site-packages (from requests->transformers) (3.1)
# Requirement already satisfied: charset-normalizer~=2.0.0; python_version >= "3" in /Users/albert/opt/anaconda3/envs/DLT_project2/lib/python3.8/site-packages (from requests->transformers) (2.0.0)

# %%
# %matplotlib inline

import json
import logging
from pathlib import Path
import random
import tarfile
import tempfile
import warnings

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# import pandas_path  # Path style access for pandas
from tqdm import tqdm

import torch                    
import torchvision
import fasttext
from torchvision import datasets, models, transforms
import torch.nn as nn
from torch.nn import functional as F
import torch.optim as optim

# %%
import ast
import pandas as pd

def load_data_lists(path):
    data_points_lists = []
    with open(path, encoding='utf-8') as f:
        lines = f.readlines()

        for line in lines:
            try:
                data_points_lists.append(ast.literal_eval(line))
            except:
                # Ignore lines with errors
                pass

    print('Found {} lines in "{}".'.format(len(lines), path))
    print('Successfully loaded {} data points from "{}".'.format(len(data_points_lists), path))
    
    return data_points_lists

COLUMN_NAMES = ['ID', 'Text', 'Sarcastic']

def construct_df(data_points_lists, column_names=COLUMN_NAMES):
    df = pd.DataFrame(data_points_lists, columns=column_names)
    df['ID'] = pd.to_numeric(df['ID'])
    df['Sarcastic'] = df['Sarcastic'].astype('bool')
    
    return df

# %%
df_train = construct_df(load_data_lists('/Users/albert/Documents/CSE8813_DLT/Sarcasm-Detection-hierarchical_fusion_model/text_data/train.txt'))

print(df_train.shape)
print(df_train.info())

display(df_train.head())
# Out:
# Found 29040 lines in "/Users/albert/Documents/CSE8813_DLT/Sarcasm-Detection-hierarchical_fusion_model/text_data/train.txt".
# Successfully loaded 29040 data points from "/Users/albert/Documents/CSE8813_DLT/Sarcasm-Detection-hierarchical_fusion_model/text_data/train.txt".
# (29040, 3)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29040 entries, 0 to 29039
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   ID         29040 non-null  int64
#  1   Text       29040 non-null  object
#  2   Sarcastic  29040 non-null  bool
# dtypes: bool(1), int64(1), object(1)
# memory usage: 482.2+ KB
# None
#                    ID                                               Text  \
# 0  910308516510011393  most # funny quotes : 21 snarky and # funny qu...
# 1  725333760762363905                   spurs # creativethinking ! <url>
# 2  840006160660983809  <user> thanks for showing up for our appointme...
# 3  854334602516733952  only a hardcore fan of sir jonny sins will get...
# 4  908913372199915520                                      haha .  # lol
#
#    Sarcastic
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True

# %%
df_val = construct_df(load_data_lists('/Users/albert/Documents/CSE8813_DLT/Sarcasm-Detection-hierarchical_fusion_model/text_data/valid.txt'), COLUMN_NAMES + ['Sarcastic_human'])
print(df_val.shape)
print(df_val.info())

display(df_val.head())
# Out:
# Found 2410 lines in "/Users/albert/Documents/CSE8813_DLT/Sarcasm-Detection-hierarchical_fusion_model/text_data/valid.txt".
# Successfully loaded 2410 data points from "/Users/albert/Documents/CSE8813_DLT/Sarcasm-Detection-hierarchical_fusion_model/text_data/valid.txt".
# (2410, 4)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2410 entries, 0 to 2409
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               2410 non-null   int64
#  1   Text             2410 non-null   object
#  2   Sarcastic        2410 non-null   bool
#  3   Sarcastic_human  2410 non-null   int64
# dtypes: bool(1), int64(2), object(1)
# memory usage: 59.0+ KB
# None
#                    ID                                               Text  \
# 0  915657464401580032  whew ... that extra <num> miles today to the g...
# 1  854678856724340736  " oh , good . now no one will know we 're here...
# 2  904892917277274112  how much of it you think is true ? has this be...
# 3  855466461296504832  <user> finally found proof that the earth is f...
# 4  927373534652805120  many ways to overcome tension & fear but nothi...
#
#    Sarcastic  Sarcastic_human
# 0       True                1
# 1       True                1
# 2       True                1
# 3       True                1
# 4       True                1

# %%
df_test = construct_df(load_data_lists('/Users/albert/Documents/CSE8813_DLT/Sarcasm-Detection-hierarchical_fusion_model/text_data/test.txt'), COLUMN_NAMES + ['Sarcastic_human'])
print(df_test.shape)
print(df_test.info())

display(df_test.head())
# Out:
# Found 2409 lines in "/Users/albert/Documents/CSE8813_DLT/Sarcasm-Detection-hierarchical_fusion_model/text_data/test.txt".
# Successfully loaded 2409 data points from "/Users/albert/Documents/CSE8813_DLT/Sarcasm-Detection-hierarchical_fusion_model/text_data/test.txt".
# (2409, 4)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2409 entries, 0 to 2408
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               2409 non-null   int64
#  1   Text             2409 non-null   object
#  2   Sarcastic        2409 non-null   bool
#  3   Sarcastic_human  2409 non-null   int64
# dtypes: bool(1), int64(2), object(1)
# memory usage: 58.9+ KB
# None
#                    ID                                               Text  \
# 0  862902619928506372  i am guessing # netflix no longer lets you gra...
# 1  892551658487631873  it 's the insensitive strikeouts at suntrust p...
# 2  853143461360480256  following the path of the river calder , so .....
# 3  918423568823840768  # westernsahara # authority has no lessons 2ge...
# 4  731617467718610944                           hey <user> great sale !
#
#    Sarcastic  Sarcastic_human
# 0       True                1
# 1       True                1
# 2       True                1
# 3       True                1
# 4       True                1

# %%
# !gdown --id 1dJERrVlp7DlNSXk-uvbbG6Rv7uvqTOKd
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1dJERrVlp7DlNSXk-uvbbG6Rv7uvqTOKd
# To: /Users/albert/Documents/CSE8813_DLT/dataset_image.z01
#   8%|██▉                                    | 55.6M/734M [00:00<00:08, 79.4MB/s]^C
# Traceback (most recent call last):
#   File "/Users/albert/opt/anaconda3/envs/DLT_project2/bin/gdown", line 10, in <module>
#     sys.exit(main())
#   File "/Users/albert/opt/anaconda3/envs/DLT_project2/lib/python3.8/site-packages/gdown/cli.py", line 145, in main
#     filename = download(
#   File "/Users/albert/opt/anaconda3/envs/DLT_project2/lib/python3.8/site-packages/gdown/download.py", line 241, in download
#     for chunk in res.iter_content(chunk_size=CHUNK_SIZE):
#   File "/Users/albert/opt/anaconda3/envs/DLT_project2/lib/python3.8/site-packages/requests/models.py", line 758, in generate
#     for chunk in self.raw.stream(chunk_size, decode_content=True):
#   File "/Users/albert/opt/anaconda3/envs/DLT_project2/lib/python3.8/site-packages/urllib3/response.py", line 576, in stream
#     data = self.read(amt=amt, decode_content=decode_content)
#   File "/Users/albert/opt/anaconda3/envs/DLT_project2/lib/python3.8/site-packages/urllib3/response.py", line 519, in read
#     data = self._fp.read(amt) if not fp_closed else b""
#   File "/Users/albert/opt/anaconda3/envs/DLT_project2/lib/python3.8/http/client.py", line 459, in read
#     n = self.readinto(b)
#   File "/Users/albert/opt/anaconda3/envs/DLT_project2/lib/python3.8/http/client.py", line 503, in readinto
#     n = self.fp.readinto(b)
#   File "/Users/albert/opt/anaconda3/envs/DLT_project2/lib/python3.8/socket.py", line 669, in readinto
#     return self._sock.recv_into(b)
#   File "/Users/albert/opt/anaconda3/envs/DLT_project2/lib/python3.8/ssl.py", line 1241, in recv_into
#     return self.read(nbytes, buffer)
#   File "/Users/albert/opt/anaconda3/envs/DLT_project2/lib/python3.8/ssl.py", line 1099, in read
#     return self._sslobj.read(len, buffer)
# KeyboardInterrupt
#   9%|███▎                                   | 63.4M/734M [00:00<00:09, 70.4MB/s]

# %%
# !gdown --id 1pODuKC4gP6-QDQonG8XTqI8w8ds68mE3
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1pODuKC4gP6-QDQonG8XTqI8w8ds68mE3
# To: /Users/albert/Documents/CSE8813_DLT/dataset_image.z02
# 100%|████████████████████████████████████████| 734M/734M [00:09<00:00, 75.8MB/s]

# %%
# !gdown --id 1mK0Nf-jv_h2bgHUCRM4_EsdTiiitZ_Uj
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1mK0Nf-jv_h2bgHUCRM4_EsdTiiitZ_Uj
# To: /Users/albert/Documents/CSE8813_DLT/dataset_image.z03
# 100%|████████████████████████████████████████| 734M/734M [00:09<00:00, 77.6MB/s]

# %%
# !gdown --id 1AOWzlOz5hmdO39dEmzhQ4z_nabgzi7Tu
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1AOWzlOz5hmdO39dEmzhQ4z_nabgzi7Tu
# To: /Users/albert/Documents/CSE8813_DLT/dataset_image.zip
# 100%|████████████████████████████████████████| 460M/460M [00:05<00:00, 77.8MB/s]

# %%
# !zip -FF dataset_image.zip --out dataset_image_full.zip
# !unzip -FF dataset_image_full.zip -d /content
# Out:
# Fix archive (-FF) - salvage what can
#  Found end record (EOCDR) - says expect 4 splits
# Scanning for entries...
#   Found spanning marker - expected as this is split (multi-disk) archive...
#  copying: dataset_image/  (0 bytes)
#  copying: dataset_image/682716753374351360.jpg  (91933 bytes)
#  copying: dataset_image/682721949072625664.jpg  (11410 bytes)
#  copying: dataset_image/682722242111774720.jpg  (55338 bytes)
#  copying: dataset_image/682727470433308672.jpg  (20498 bytes)
#  copying: dataset_image/682751920956641280.jpg  (47665 bytes)
#  copying: dataset_image/682762265041321989.jpg  (64143 bytes)
#  copying: dataset_image/682773510196822016.jpg  (111873 bytes)
#  copying: dataset_image/682783114343518208.jpg  (97818 bytes)
#  copying: dataset_image/682784347305410560.jpg  (47626 bytes)
#  copying: dataset_image/682836685323956224.jpg  (18549 bytes)
#  copying: dataset_image/682864661813981184.jpg  (167523 bytes)
#  copying: dataset_image/682883715681390593.jpg  (109367 bytes)
#  copying: dataset_image/682906033312935936.jpg  (18797 bytes)
#  copying: dataset_image/682931582357893120.jpg  (49801 bytes)
#  copying: dataset_image/682931696845611008.jpg  (32039 bytes)
#  copying: dataset_image/682934584527466496.jpg  (133899 bytes)
#  copying: dataset_image/682987076128657408.jpg  (86502 bytes)
#  copying: dataset_image/683009023247953921.jpg  (107671 bytes)
#  copying: dataset_image/683062203268780032.jpg  (102663 bytes)
#  copying: dataset_image/683087755019026432.jpg  (163713 bytes)
#  copying: dataset_image/683090662418288640.jpg  (78227 bytes)
#  copying: dataset_image/683181977726418945.jpg  (176476 bytes)
#  copying: dataset_image/683182680360529920.jpg  (36085 bytes)
#  copying: dataset_image/683215653113823232.jpg  (267756 bytes)
#  copying: dataset_image/683250958717956097.jpg  (58673 bytes)
#  copying: dataset_image/683275769330712577.jpg  (36647 bytes)
#  copying: dataset_image/683293152787214336.jpg  (154955 bytes)
#  copying: dataset_image/683295117847969793.jpg  (131970 bytes)
#  copying: dataset_image/683302904363638784.jpg  (24484 bytes)
#  copying: dataset_image/683308322259398658.jpg  (61710 bytes)
#  copying: dataset_image/683313760342249472.jpg  (31394 bytes)
#  copying: dataset_image/683324835745902592.jpg  (54359 bytes)
#  copying: dataset_image/683337444511498240.jpg  (34541 bytes)
#  copying: dataset_image/683344545027854336.jpg  (24902 bytes)
#  copying: dataset_image/683355503947309056.jpg  (39891 bytes)
#  copying: dataset_image/683363557321388032.jpg  (175461 bytes)
#  copying: dataset_image/683364611513397248.jpg  (153445 bytes)
#  copying: dataset_image/683365234229248004.jpg  (96879 bytes)
#  copying: dataset_image/683405203328991232.jpg  (25425 bytes)
#  copying: dataset_image/683417001570742274.jpg  (66256 bytes)
#  copying: dataset_image/683431160127590400.jpg  (81837 bytes)
#  copying: dataset_image/683800787995066368.jpg  (108781 bytes)
#  copying: dataset_image/683810612518993920.jpg  (97517 bytes)
#  copying: dataset_image/683836032756920320.jpg  (68198 bytes)
#  copying: dataset_image/683843373514514432.jpg  (26698 bytes)
#  copying: dataset_image/683854138535358465.jpg  (123680 bytes)
#  copying: dataset_image/683859183511285760.jpg  (75123 bytes)
#  copying: dataset_image/683868783547551744.jpg  (120165 bytes)
#  copying: dataset_image/683877353898950656.jpg  (91772 bytes)
#  copying: dataset_image/683882326179233793.jpg  (117666 bytes)
#  copying: dataset_image/683882952938278912.jpg  (158944 bytes)
#  copying: dataset_image/683889125745922048.jpg  (43899 bytes)
#  copying: dataset_image/683894557021319169.jpg  (195185 bytes)
#  copying: dataset_image/683926586698141696.jpg  (185718 bytes)
#  copying: dataset_image/683945720840323072.jpg  (273634 bytes)
#  copying: dataset_image/683958598796505088.jpg  (112868 bytes)
#  copying: dataset_image/683979570568105985.jpg  (60227 bytes)
#  copying: dataset_image/684001784088686592.jpg  (149630 bytes)
#  copying: dataset_image/684018093459390464.jpg  (309867 bytes)
#  copying: dataset_image/684036010636804096.jpg  (70915 bytes)
#  copying: dataset_image/684042671741091840.jpg  (57641 bytes)
#  copying: dataset_image/684043013388120065.jpg  (34165 bytes)
#  copying: dataset_image/684043024830181376.jpg  (79118 bytes)
#  copying: dataset_image/684047142906761216.jpg  (3952 bytes)
#  copying: dataset_image/684048166224838656.jpg  (109904 bytes)
#  copying: dataset_image/684051880524161026.jpg  (17238 bytes)
#  copying: dataset_image/684110397914386433.jpg  (15603 bytes)
#  copying: dataset_image/684110747933237249.jpg  (110640 bytes)
#  copying: dataset_image/684127708486496259.jpg  (30586 bytes)
#  copying: dataset_image/684140022417780739.jpg  (99943 bytes)
#  copying: dataset_image/684160451572281344.jpg  (42694 bytes)
#  copying: dataset_image/684162257475997696.jpg  (147347 bytes)
#  copying: dataset_image/684530584765333504.jpg  (184685 bytes)
#  copying: dataset_image/684536371386683392.jpg  (77169 bytes)
#  copying: dataset_image/684585518105899008.jpg  (52437 bytes)
#  copying: dataset_image/684590148672077824.jpg  (17988 bytes)
#  copying: dataset_image/684607693915439104.jpg  (42000 bytes)
#  copying: dataset_image/684633048483106816.jpg  (83692 bytes)
#  copying: dataset_image/684649006606061568.jpg  (75174 bytes)
#  copying: dataset_image/684667398843047936.jpg  (34176 bytes)
#  copying: dataset_image/684698671594778624.jpg  (36945 bytes)
#  copying: dataset_image/684741930924793856.jpg  (97792 bytes)
#  copying: dataset_image/684746305810239488.jpg  (32530 bytes)
#  copying: dataset_image/684751136490962945.jpg  (54245 bytes)
#  copying: dataset_image/684751563454205952.jpg  (30990 bytes)
#  copying: dataset_image/684751830425833472.jpg  (64691 bytes)
#  copying: dataset_image/684788302143078400.jpg  (96274 bytes)
#  copying: dataset_image/684821191039840256.jpg  (21586 bytes)
#  copying: dataset_image/684835175738568704.jpg  (26289 bytes)
#  copying: dataset_image/684848251552567298.jpg  (137389 bytes)
#  copying: dataset_image/684888905758318592.jpg  (53155 bytes)
#  copying: dataset_image/684920023475994626.jpg  (111862 bytes)
#  copying: dataset_image/684921998305312768.jpg  (71893 bytes)
#  copying: dataset_image/684922233274380288.jpg  (103810 bytes)
#  copying: dataset_image/684923881421930496.jpg  (70964 bytes)
#  copying: dataset_image/684934265751093248.jpg  (125303 bytes)
#  copying: dataset_image/684951892347252736.jpg  (164755 bytes)
#  copying: dataset_image/684979497074991104.jpg  (114987 bytes)
#  copying: dataset_image/685079733478932481.jpg  (20648 bytes)
#  copying: dataset_image/685103804581216257.jpg  (60434 bytes)
#  copying: dataset_image/685107977460686849.jpg  (45470 bytes)
#  copying: dataset_image/685113505276649473.jpg  (33435 bytes)
#  copying: dataset_image/685117054953877505.jpg  (107792 bytes)
#  copying: dataset_image/685156039159853056.jpg  (104711 bytes)
#  copying: dataset_image/685159825995505665.jpg  (15130 bytes)
#  copying: dataset_image/685164083117608960.jpg  (90757 bytes)
#  copying: dataset_image/685168383738785792.jpg  (56556 bytes)
#  copying: dataset_image/685173919058407424.jpg  (39807 bytes)
#  copying: dataset_image/685175113482944512.jpg  (40495 bytes)
#  copying: dataset_image/685183064826351617.jpg  (16822 bytes)
#  copying: dataset_image/685190077555826692.jpg  (95773 bytes)
#  copying: dataset_image/685190289431113728.jpg  (35294 bytes)
#  copying: dataset_image/685204034815275008.jpg  (117455 bytes)
#  copying: dataset_image/685221022937821184.jpg  (252751 bytes)
#  copying: dataset_image/685234721282981889.jpg  (5380 bytes)
#  copying: dataset_image/685236198298808320.jpg  (159529 bytes)
#  copying: dataset_image/685236400854188033.jpg  (110098 bytes)
#  copying: dataset_image/685248241412145152.jpg  (137420 bytes)
#  copying: dataset_image/685269360940822528.jpg  (41687 bytes)
#  copying: dataset_image/685271249187110912.jpg  (66266 bytes)
#  copying: dataset_image/685276611042766849.jpg  (86141 bytes)
#  copying: dataset_image/685314759353348096.jpg  (43593 bytes)
#  copying: dataset_image/685357510484738048.jpg  (131590 bytes)
#  copying: dataset_image/685359129414774784.jpg  (71738 bytes)
#  copying: dataset_image/685363041110634496.jpg  (85467 bytes)
#  copying: dataset_image/685385028273090560.jpg  (155364 bytes)
#  copying: dataset_image/685414412103069696.jpg  (188018 bytes)
#  copying: dataset_image/685480944191586304.jpg  (42169 bytes)
#  copying: dataset_image/685491413409112065.jpg  (208017 bytes)
#  copying: dataset_image/685499717149569024.jpg  (113722 bytes)
#  copying: dataset_image/685512351207022592.jpg  (75449 bytes)
#  copying: dataset_image/685517820558479360.jpg  (69614 bytes)
#  copying: dataset_image/685520313069776896.jpg  (126272 bytes)
#  copying: dataset_image/685538617566052352.jpg  (44243 bytes)
#  copying: dataset_image/685547443598004225.jpg  (88069 bytes)
#  copying: dataset_image/685548576630521856.jpg  (151978 bytes)
#  copying: dataset_image/685553472083734529.jpg  (19690 bytes)
#  copying: dataset_image/685561705426989057.jpg  (96706 bytes)
#  copying: dataset_image/685565163127320579.jpg  (54757 bytes)
#  copying: dataset_image/685570843477319680.jpg  (141009 bytes)
#  copying: dataset_image/685575068215279618.jpg  (146554 bytes)
#  copying: dataset_image/685576450364289026.jpg  (126272 bytes)
#  copying: dataset_image/685579652161757189.jpg  (73943 bytes)
#  copying: dataset_image/685587227791851520.jpg  (97006 bytes)
#  copying: dataset_image/685594638464499712.jpg  (38838 bytes)
#  copying: dataset_image/685601583879598084.jpg  (18604 bytes)
#  copying: dataset_image/685610832085053444.jpg  (34514 bytes)
#  copying: dataset_image/685622559937708032.jpg  (181005 bytes)
#  copying: dataset_image/685631120298213376.jpg  (101013 bytes)
#  copying: dataset_image/685656680495845378.jpg  (77730 bytes)
#  copying: dataset_image/685712147956023296.jpg  (94924 bytes)
#  copying: dataset_image/685766032414224385.jpg  (69255 bytes)
#  copying: dataset_image/685817158652280832.jpg  (31233 bytes)
#  copying: dataset_image/685857038681899010.jpg  (69662 bytes)
#  copying: dataset_image/685870962689064960.jpg  (72458 bytes)
#  copying: dataset_image/685874262998028288.jpg  (100538 bytes)
#  copying: dataset_image/685875890841108480.jpg  (109428 bytes)
#  copying: dataset_image/685875930401779712.jpg  (40862 bytes)
#  copying: dataset_image/685908290010742784.jpg  (229240 bytes)
#  copying: dataset_image/685926903509872640.jpg  (83589 bytes)
#  copying: dataset_image/685931813861240833.jpg  (45122 bytes)
#  copying: dataset_image/685941579341664257.jpg  (121564 bytes)
#  copying: dataset_image/685982606496776192.jpg  (123558 bytes)
#  copying: dataset_image/685996770829168640.jpg  (115359 bytes)
#  copying: dataset_image/685999243874676736.jpg  (88252 bytes)
#  copying: dataset_image/686013652021809152.jpg  (110422 bytes)
#  copying: dataset_image/686029041900507136.jpg  (142632 bytes)
#  copying: dataset_image/686050853120167936.jpg  (160007 bytes)
#  copying: dataset_image/686074568759357441.jpg  (72882 bytes)
#  copying: dataset_image/686096922868867072.jpg  (218620 bytes)
#  copying: dataset_image/686126823592177664.jpg  (24638 bytes)
#  copying: dataset_image/686222316431257600.jpg  (26645 bytes)
#  copying: dataset_image/686244213932048385.jpg  (2146 bytes)
#  copying: dataset_image/686249757103271937.jpg  (86242 bytes)
#  copying: dataset_image/686253463446138880.jpg  (44714 bytes)
#  copying: dataset_image/686253993769734145.jpg  (34976 bytes)
#  copying: dataset_image/686269922779873280.jpg  (19039 bytes)
#  copying: dataset_image/686283458059059200.jpg  (144974 bytes)
#  copying: dataset_image/686309303913820161.jpg  (67801 bytes)
#  copying: dataset_image/686323557958291456.jpg  (21595 bytes)
#  copying: dataset_image/686522354575486976.jpg  (145464 bytes)
#  copying: dataset_image/686540784653463552.jpg  (49468 bytes)
#  copying: dataset_image/686572545265504256.jpg  (44954 bytes)
#  copying: dataset_image/686574932990410754.jpg  (57996 bytes)
#  copying: dataset_image/686575579328589824.jpg  (227484 bytes)
#  copying: dataset_image/686579193614761984.jpg  (111943 bytes)
#  copying: dataset_image/686587990236348416.jpg  (18022 bytes)
#  copying: dataset_image/686590150235807744.jpg  (55198 bytes)
#  copying: dataset_image/686620435534987265.jpg  (43670 bytes)
#  copying: dataset_image/686624979966910464.jpg  (48693 bytes)
#  copying: dataset_image/686649475776036867.jpg  (49227 bytes)
#  copying: dataset_image/686667554811691009.jpg  (59893 bytes)
#  copying: dataset_image/686670836577742848.jpg  (56516 bytes)
#  copying: dataset_image/686681115915059201.jpg  (57593 bytes)
#  copying: dataset_image/686698926104272896.jpg  (27400 bytes)
#  copying: dataset_image/686704697814614016.jpg  (79038 bytes)
#  copying: dataset_image/686708138075107328.jpg  (65116 bytes)
#  copying: dataset_image/686721906909683712.jpg  (19867 bytes)
#  copying: dataset_image/686724563493720064.jpg  (6271 bytes)
#  copying: dataset_image/686728005985681412.jpg  (59923 bytes)
#  copying: dataset_image/686763823085293574.jpg  (110284 bytes)
#  copying: dataset_image/686766977612791809.jpg  (122688 bytes)
#  copying: dataset_image/686774491976839173.jpg  (50349 bytes)
#  copying: dataset_image/686786826254745600.jpg  (28646 bytes)
#  copying: dataset_image/686864444924760064.jpg  (124354 bytes)
#  copying: dataset_image/686885994684125185.jpg  (354356 bytes)
#  copying: dataset_image/686893605621874688.jpg  (148437 bytes)
#  copying: dataset_image/686900219292839939.jpg  (113897 bytes)
#  copying: dataset_image/686906870217490437.jpg  (73926 bytes)
#  copying: dataset_image/686916775582109698.jpg  (167879 bytes)
#  copying: dataset_image/686926157288202241.jpg  (24812 bytes)
#  copying: dataset_image/686937481288138752.jpg  (77503 bytes)
#  copying: dataset_image/686955918727213057.jpg  (59898 bytes)
#  copying: dataset_image/686988004708106241.jpg  (19857 bytes)
#  copying: dataset_image/686995430366904321.jpg  (66294 bytes)
#  copying: dataset_image/687002701318717440.jpg  (54314 bytes)
#  copying: dataset_image/687017855045492736.jpg  (94499 bytes)
#  copying: dataset_image/687037430717898753.jpg  (82053 bytes)
#  copying: dataset_image/687037688856338432.jpg  (80771 bytes)
#  copying: dataset_image/687046254455566337.jpg  (41147 bytes)
#  copying: dataset_image/687053223753060354.jpg  (41147 bytes)
#  copying: dataset_image/687063869215342592.jpg  (71561 bytes)
#  copying: dataset_image/687071770524819456.jpg  (37193 bytes)
#  copying: dataset_image/687097423743696896.jpg  (109364 bytes)
#  copying: dataset_image/687117399187828736.jpg  (187180 bytes)
#  copying: dataset_image/687136547032793088.jpg  (54980 bytes)
#  copying: dataset_image/687137751943266304.jpg  (68780 bytes)
#  copying: dataset_image/687144271955103744.jpg  (108465 bytes)
#  copying: dataset_image/687155161697894400.jpg  (73600 bytes)
#  copying: dataset_image/687178819929767936.jpg  (156144 bytes)
#  copying: dataset_image/687208244943695872.jpg  (87423 bytes)
#  copying: dataset_image/687217642302795776.jpg  (49309 bytes)
#  copying: dataset_image/687275544996634624.jpg  (69284 bytes)
#  copying: dataset_image/687283711256035329.jpg  (169204 bytes)
#  copying: dataset_image/687298676860010497.jpg  (100244 bytes)
#  copying: dataset_image/687312681863233536.jpg  (62691 bytes)
#  copying: dataset_image/687326083256070144.jpg  (82231 bytes)
#  copying: dataset_image/687328903120203776.jpg  (51228 bytes)
#  copying: dataset_image/687332343367995392.jpg  (28516 bytes)
#  copying: dataset_image/687339121505734656.jpg  (9532 bytes)
#  copying: dataset_image/687339807463337985.jpg  (69452 bytes)
#  copying: dataset_image/687372373268430848.jpg  (3806 bytes)
#  copying: dataset_image/687379180409860096.jpg  (189495 bytes)
#  copying: dataset_image/687383830508998656.jpg  (140948 bytes)
#  copying: dataset_image/687393941067558912.jpg  (19019 bytes)
#  copying: dataset_image/687435123294355457.jpg  (50276 bytes)
#  copying: dataset_image/687440182027497472.jpg  (4924 bytes)
#  copying: dataset_image/687462795638607872.jpg  (114725 bytes)
#  copying: dataset_image/687475009816801281.jpg  (31417 bytes)
#  copying: dataset_image/687475296778366976.jpg  (125688 bytes)
#  copying: dataset_image/687478220090806273.jpg  (109703 bytes)
#  copying: dataset_image/687504091639988225.jpg  (198682 bytes)
#  copying: dataset_image/687536800508821504.jpg  (79606 bytes)
#  copying: dataset_image/687538447997784064.jpg  (102059 bytes)
#  copying: dataset_image/687550286286565376.jpg  (106995 bytes)
#  copying: dataset_image/687599189438631936.jpg  (128904 bytes)
#  copying: dataset_image/687619209195614208.jpg  (67482 bytes)
#  copying: dataset_image/687639534926839808.jpg  (38086 bytes)
#  copying: dataset_image/687651957268328448.jpg  (33230 bytes)
#  copying: dataset_image/687653525757673473.jpg  (89507 bytes)
#  copying: dataset_image/687655177936093184.jpg  (101298 bytes)
#  copying: dataset_image/687661976533610496.jpg  (189156 bytes)
#  copying: dataset_image/687663134056693761.jpg  (60593 bytes)
#  copying: dataset_image/687673919357071360.jpg  (95403 bytes)
#  copying: dataset_image/687686464428113920.jpg  (141152 bytes)
#  copying: dataset_image/687691982114701312.jpg  (69723 bytes)
#  copying: dataset_image/687723279520526336.jpg  (74955 bytes)
#  copying: dataset_image/687729338360442880.jpg  (107386 bytes)
#  copying: dataset_image/687732490665000961.jpg  (29358 bytes)
#  copying: dataset_image/687733379094056960.jpg  (34348 bytes)
#  copying: dataset_image/687741234920599553.jpg  (167443 bytes)
#  copying: dataset_image/687748094427971584.jpg  (80034 bytes)
#  copying: dataset_image/687751173768495104.jpg  (115419 bytes)
#  copying: dataset_image/687767505465573377.jpg  (50791 bytes)
#  copying: dataset_image/687800927617724416.jpg  (54485 bytes)
#  copying: dataset_image/687821553069772801.jpg  (213376 bytes)
#  copying: dataset_image/687826579599196160.jpg  (83172 bytes)
#  copying: dataset_image/687833630098362368.jpg  (100237 bytes)
#  copying: dataset_image/687837109395288064.jpg  (32156 bytes)
#  copying: dataset_image/687842181323853824.jpg  (42833 bytes)
#  copying: dataset_image/687849753640435713.jpg  (87830 bytes)
#  copying: dataset_image/687919258567770112.jpg  (51916 bytes)
#  copying: dataset_image/687922927430275072.jpg  (211672 bytes)
#  copying: dataset_image/687923155315326977.jpg  (63471 bytes)
#  copying: dataset_image/687946942542966784.jpg  (108291 bytes)
#  copying: dataset_image/687973976103063552.jpg  (189549 bytes)
#  copying: dataset_image/687978177155575809.jpg  (64135 bytes)
#  copying: dataset_image/687988631546507265.jpg  (47186 bytes)
#  copying: dataset_image/687998090146496512.jpg  (25217 bytes)
#  copying: dataset_image/688011491795189760.jpg  (195205 bytes)
#  copying: dataset_image/688013070384381952.jpg  (139304 bytes)
#  copying: dataset_image/688014349953286145.jpg  (50741 bytes)
#  copying: dataset_image/688016874370674695.jpg  (118356 bytes)
#  copying: dataset_image/688017132899188736.jpg  (118394 bytes)
#  copying: dataset_image/688019101659344896.jpg  (140281 bytes)
#  copying: dataset_image/688021313949167616.jpg  (31537 bytes)
#  copying: dataset_image/688022995735080961.jpg  (68719 bytes)
#  copying: dataset_image/688044840412565505.jpg  (128057 bytes)
#  copying: dataset_image/688045940477968384.jpg  (46582 bytes)
#  copying: dataset_image/688048010777853952.jpg  (52515 bytes)
#  copying: dataset_image/688070697055313920.jpg  (125051 bytes)
#  copying: dataset_image/688074706298253313.jpg  (111715 bytes)
#  copying: dataset_image/688075055016886272.jpg  (171409 bytes)
#  copying: dataset_image/688083478018146304.jpg  (109697 bytes)
#  copying: dataset_image/688103947614064641.jpg  (155902 bytes)
#  copying: dataset_image/688104360199323648.jpg  (84393 bytes)
#  copying: dataset_image/688123616454520833.jpg  (172530 bytes)
#  copying: dataset_image/688124538454802432.jpg  (103958 bytes)
#  copying: dataset_image/688136577806016514.jpg  (6328 bytes)
#  copying: dataset_image/688140954750955520.jpg  (212643 bytes)
#  copying: dataset_image/688180666911952897.jpg  (134653 bytes)
#  copying: dataset_image/688184681863331840.jpg  (60895 bytes)
#  copying: dataset_image/688186042134822914.jpg  (188751 bytes)
#  copying: dataset_image/688194261305536513.jpg  (27573 bytes)
#  copying: dataset_image/688253637584265217.jpg  (59671 bytes)
#  copying: dataset_image/688280585899511808.jpg  (74084 bytes)
#  copying: dataset_image/688299479263498240.jpg  (56009 bytes)
#  copying: dataset_image/688325431141990400.jpg  (178182 bytes)
#  copying: dataset_image/688338958577717248.jpg  (101497 bytes)
#  copying: dataset_image/688345649994055680.jpg  (44743 bytes)
#  copying: dataset_image/688374085945049088.jpg  (33155 bytes)
#  copying: dataset_image/688381259328913408.jpg  (80665 bytes)
#  copying: dataset_image/688411498272571392.jpg  (59879 bytes)
#  copying: dataset_image/688413325433028608.jpg  (58148 bytes)
#  copying: dataset_image/688434905265483776.jpg  (89823 bytes)
#  copying: dataset_image/688439479607009280.jpg  (40143 bytes)
#  copying: dataset_image/688452984586502144.jpg  (136678 bytes)
#  copying: dataset_image/688454234367377408.jpg  (269423 bytes)
#  copying: dataset_image/688460191130603521.jpg  (105391 bytes)
#  copying: dataset_image/688471306442944512.jpg  (205230 bytes)
#  copying: dataset_image/688474231651176448.jpg  (24725 bytes)
#  copying: dataset_image/688526083348500484.jpg  (63703 bytes)
#  copying: dataset_image/688536913830113280.jpg  (59195 bytes)
#  copying: dataset_image/688539934605484033.jpg  (44704 bytes)
#  copying: dataset_image/688562709873446912.jpg  (8277 bytes)
#  copying: dataset_image/688606169623998464.jpg  (96944 bytes)
#  copying: dataset_image/688640516758630402.jpg  (41047 bytes)
#  copying: dataset_image/688650921929080832.jpg  (51000 bytes)
#  copying: dataset_image/688662865016958976.jpg  (33055 bytes)
#  copying: dataset_image/688679549664673792.jpg  (47251 bytes)
#  copying: dataset_image/688682109037228033.jpg  (72720 bytes)
#  copying: dataset_image/688706915757625344.jpg  (71673 bytes)
#  copying: dataset_image/688734735175004161.jpg  (83108 bytes)
#  copying: dataset_image/688748657982713857.jpg  (9811 bytes)
#  copying: dataset_image/688750591502381056.jpg  (44940 bytes)
#  copying: dataset_image/688766388324950016.jpg  (39220 bytes)
#  copying: dataset_image/688766975820992512.jpg  (150709 bytes)
#  copying: dataset_image/688779229627035650.jpg  (34976 bytes)
#  copying: dataset_image/688779926409969665.jpg  (72863 bytes)
#  copying: dataset_image/688783571381649408.jpg  (90500 bytes)
#  copying: dataset_image/688794329465270272.jpg  (115528 bytes)
#  copying: dataset_image/688804762381357057.jpg  (198162 bytes)
#  copying: dataset_image/688833309502222336.jpg  (60366 bytes)
#  copying: dataset_image/688839242819203072.jpg  (83802 bytes)
#  copying: dataset_image/688839877597728769.jpg  (20434 bytes)
#  copying: dataset_image/688911206149677057.jpg  (25210 bytes)
#  copying: dataset_image/688921289407397888.jpg  (94207 bytes)
#  copying: dataset_image/688931689758863360.jpg  (43893 bytes)
#  copying: dataset_image/688948987307507712.jpg  (46417 bytes)
#  copying: dataset_image/689033889923219456.jpg  (33608 bytes)
#  copying: dataset_image/689052142003294209.jpg  (87691 bytes)
#  copying: dataset_image/689096382574112772.jpg  (11331 bytes)
#  copying: dataset_image/689120428409909248.jpg  (95458 bytes)
#  copying: dataset_image/689133010663288833.jpg  (94996 bytes)
#  copying: dataset_image/689146173035298818.jpg  (35462 bytes)
#  copying: dataset_image/689149960797945856.jpg  (16035 bytes)
#  copying: dataset_image/689152404487417857.jpg  (91253 bytes)
#  copying: dataset_image/689171316231016448.jpg  (173208 bytes)
#  copying: dataset_image/689173117193834496.jpg  (160832 bytes)
#  copying: dataset_image/689183603926810625.jpg  (77058 bytes)
#  copying: dataset_image/689186484902064128.jpg  (84750 bytes)
#  copying: dataset_image/689219730796707840.jpg  (196886 bytes)
#  copying: dataset_image/689240781643579392.jpg  (256922 bytes)
#  copying: dataset_image/689242025519091714.jpg  (46782 bytes)
#  copying: dataset_image/689269156416491520.jpg  (89871 bytes)
#  copying: dataset_image/689276259809923073.jpg  (2673 bytes)
#  copying: dataset_image/689357345588125696.jpg  (127317 bytes)
#  copying: dataset_image/689385100178432000.jpg  (78955 bytes)
#  copying: dataset_image/689446393040142336.jpg  (111015 bytes)
#  copying: dataset_image/689456651997347841.jpg  (49974 bytes)
#  copying: dataset_image/689457017308602368.jpg  (69941 bytes)
#  copying: dataset_image/689481175941808128.jpg  (169699 bytes)
#  copying: dataset_image/689481578389499904.jpg  (56597 bytes)
#  copying: dataset_image/689484733433032704.jpg  (81187 bytes)
#  copying: dataset_image/689486061983019009.jpg  (343228 bytes)
#  copying: dataset_image/689487804133289984.jpg  (10951 bytes)
#  copying: dataset_image/689492583442087936.jpg  (66854 bytes)
#  copying: dataset_image/689501721966415873.jpg  (121088 bytes)
#  copying: dataset_image/689594508460298244.jpg  (141343 bytes)
#  copying: dataset_image/689600450018938880.jpg  (193289 bytes)
#  copying: dataset_image/689637362058440705.jpg  (148708 bytes)
#  copying: dataset_image/689667649878540289.jpg  (98590 bytes)
#  copying: dataset_image/689681644987551744.jpg  (41686 bytes)
#  copying: dataset_image/689691065503326208.jpg  (99333 bytes)
#  copying: dataset_image/689704577847918592.jpg  (150083 bytes)
#  copying: dataset_image/689751315505926144.jpg  (88386 bytes)
#  copying: dataset_image/689752136435929088.jpg  (139234 bytes)
#  copying: dataset_image/689782673112367104.jpg  (71289 bytes)
#  copying: dataset_image/689796494157832193.jpg  (32108 bytes)
#  copying: dataset_image/689796910463467520.jpg  (154981 bytes)
#  copying: dataset_image/689816370658349057.jpg  (44324 bytes)
#  copying: dataset_image/689825646760042497.jpg  (88669 bytes)
#  copying: dataset_image/689841858198007809.jpg  (139986 bytes)
#  copying: dataset_image/689845434211143680.jpg  (71462 bytes)
#  copying: dataset_image/689845804610158592.jpg  (91876 bytes)
#  copying: dataset_image/689850516734615552.jpg  (146748 bytes)
#  copying: dataset_image/689852887963471872.jpg  (19184 bytes)
#  copying: dataset_image/689852968066224128.jpg  (99726 bytes)
#  copying: dataset_image/689854555199250433.jpg  (18159 bytes)
#  copying: dataset_image/689866246855266304.jpg  (117668 bytes)
#  copying: dataset_image/689868642260029440.jpg  (8392 bytes)
#  copying: dataset_image/689871277205671936.jpg  (108586 bytes)
#  copying: dataset_image/689872913210695680.jpg  (166005 bytes)
#  copying: dataset_image/689875739315965952.jpg  (86453 bytes)
#  copying: dataset_image/689876038046892032.jpg  (105700 bytes)
#  copying: dataset_image/689878733424087040.jpg  (161341 bytes)
#  copying: dataset_image/689884768759123972.jpg  (208335 bytes)
#  copying: dataset_image/689885764633497600.jpg  (42367 bytes)
#  copying: dataset_image/689887669346766849.jpg  (102639 bytes)
#  copying: dataset_image/689893996626341890.jpg  (44324 bytes)
#  copying: dataset_image/689911550803582981.jpg  (135497 bytes)
#  copying: dataset_image/689927193468735489.jpg  (121936 bytes)
#  copying: dataset_image/689933352053374976.jpg  (31065 bytes)
#  copying: dataset_image/689951492443410433.jpg  (85879 bytes)
#  copying: dataset_image/689969145895591936.jpg  (72543 bytes)
#  copying: dataset_image/690010469638234113.jpg  (32673 bytes)
#  copying: dataset_image/690019977588555776.jpg  (28148 bytes)
#  copying: dataset_image/690029618150166528.jpg  (22472 bytes)
#  copying: dataset_image/690051618126086144.jpg  (74590 bytes)
#  copying: dataset_image/690066296097087489.jpg  (74590 bytes)
#  copying: dataset_image/690122173579685890.jpg  (165108 bytes)
#  copying: dataset_image/690130217646555136.jpg  (232858 bytes)
#  copying: dataset_image/690138402499469312.jpg  (182194 bytes)
#  copying: dataset_image/690138976276070400.jpg  (47139 bytes)
#  copying: dataset_image/690157363538567172.jpg  (110962 bytes)
#  copying: dataset_image/690165552749375488.jpg  (55286 bytes)
#  copying: dataset_image/690169534460878848.jpg  (34327 bytes)
#  copying: dataset_image/690171742598381569.jpg  (129171 bytes)
#  copying: dataset_image/690176182722154496.jpg  (99536 bytes)
#  copying: dataset_image/690184007951089665.jpg  (72298 bytes)
#  copying: dataset_image/690195685891805184.jpg  (60596 bytes)
#  copying: dataset_image/690220749399851008.jpg  (99865 bytes)
#  copying: dataset_image/690226000622424064.jpg  (72358 bytes)
#  copying: dataset_image/690236729790468096.jpg  (250764 bytes)
#  copying: dataset_image/690248594927017984.jpg  (16275 bytes)
#  copying: dataset_image/690258795734437889.jpg  (49631 bytes)
#  copying: dataset_image/690282226718642176.jpg  (13815 bytes)
#  copying: dataset_image/690294558312263682.jpg  (172279 bytes)
#  copying: dataset_image/690314542929186816.jpg  (96393 bytes)
#  copying: dataset_image/690319391959941124.jpg  (159282 bytes)
#  copying: dataset_image/690358339189002240.jpg  (84370 bytes)
#  copying: dataset_image/690362083087613952.jpg  (20273 bytes)
#  copying: dataset_image/690363048326987777.jpg  (26723 bytes)
#  copying: dataset_image/690383035896823809.jpg  (123728 bytes)
#  copying: dataset_image/690401917042835456.jpg  (86440 bytes)
#  copying: dataset_image/690416364377477120.jpg  (94244 bytes)
#  copying: dataset_image/690428189592666112.jpg  (44224 bytes)
#  copying: dataset_image/690447117052084224.jpg  (100708 bytes)
#  copying: dataset_image/690455195864662016.jpg  (149665 bytes)
#  copying: dataset_image/690455538828709889.jpg  (97071 bytes)
#  copying: dataset_image/690474653064781824.jpg  (173318 bytes)
#  copying: dataset_image/690484087014948864.jpg  (48065 bytes)
#  copying: dataset_image/690535141689663488.jpg  (185038 bytes)
#  copying: dataset_image/690543069599506432.jpg  (99580 bytes)
#  copying: dataset_image/690561903580418048.jpg  (169197 bytes)
#  copying: dataset_image/690563526776066048.jpg  (287222 bytes)
#  copying: dataset_image/690589622594838528.jpg  (37846 bytes)
#  copying: dataset_image/690633649985851392.jpg  (21570 bytes)
#  copying: dataset_image/690675425681346560.jpg  (53067 bytes)
#  copying: dataset_image/690678117094952961.jpg  (75065 bytes)
#  copying: dataset_image/690684507008032768.jpg  (99338 bytes)
#  copying: dataset_image/690700870648922113.jpg  (51071 bytes)
#  copying: dataset_image/690764914873516032.jpg  (76450 bytes)
#  copying: dataset_image/690768935185223680.jpg  (114828 bytes)
#  copying: dataset_image/690804418376130560.jpg  (24944 bytes)
#  copying: dataset_image/690847752847245312.jpg  (75855 bytes)
#  copying: dataset_image/690898693743075328.jpg  (70448 bytes)
#  copying: dataset_image/690907113388969984.jpg  (144737 bytes)
#  copying: dataset_image/690908985428312064.jpg  (89218 bytes)
#  copying: dataset_image/690915881082343424.jpg  (84308 bytes)
#  copying: dataset_image/690925366144278529.jpg  (71722 bytes)
#  copying: dataset_image/690952190081441792.jpg  (96749 bytes)
#  copying: dataset_image/690952642521100289.jpg  (112618 bytes)
#  copying: dataset_image/690957971673604096.jpg  (36496 bytes)
#  copying: dataset_image/690961198108516352.jpg  (81602 bytes)
#  copying: dataset_image/690965828808904704.jpg  (30780 bytes)
#  copying: dataset_image/690972372124434433.jpg  (35208 bytes)
#  copying: dataset_image/690983395598409728.jpg  (122126 bytes)
#  copying: dataset_image/690994509862297601.jpg  (20814 bytes)
#  copying: dataset_image/691072273537630209.jpg  (107118 bytes)
#  copying: dataset_image/691074384035999744.jpg  (144840 bytes)
#  copying: dataset_image/691095203411812355.jpg  (79632 bytes)
#  copying: dataset_image/691163819633082369.jpg  (36850 bytes)
#  copying: dataset_image/691174404622008321.jpg  (99403 bytes)
#  copying: dataset_image/691192278547828736.jpg  (51585 bytes)
#  copying: dataset_image/691288239181860864.jpg  (194826 bytes)
#  copying: dataset_image/691293762740445185.jpg  (34501 bytes)
#  copying: dataset_image/691296365410947072.jpg  (65914 bytes)
#  copying: dataset_image/691301847588544517.jpg  (55075 bytes)
#  copying: dataset_image/691304685756641280.jpg  (120399 bytes)
#  copying: dataset_image/691321835141611527.jpg  (119633 bytes)
#  copying: dataset_image/691327606617079809.jpg  (186606 bytes)
#  copying: dataset_image/691327901497716737.jpg  (167319 bytes)
#  copying: dataset_image/691345881732419584.jpg  (25835 bytes)
#  copying: dataset_image/691372367214284800.jpg  (269423 bytes)
#  copying: dataset_image/691380147434459136.jpg  (142256 bytes)
#  copying: dataset_image/691396223287312384.jpg  (66212 bytes)
#  copying: dataset_image/691441062565453824.jpg  (98873 bytes)
#  copying: dataset_image/691578360242294784.jpg  (150798 bytes)
#  copying: dataset_image/691608928006881280.jpg  (76468 bytes)
#  copying: dataset_image/691612316580876290.jpg  (151449 bytes)
#  copying: dataset_image/691617977238736896.jpg  (148837 bytes)
#  copying: dataset_image/691649604924882944.jpg  (44940 bytes)
#  copying: dataset_image/691654731664592897.jpg  (202794 bytes)
#  copying: dataset_image/691662493102555136.jpg  (119280 bytes)
#  copying: dataset_image/691662830299324417.jpg  (97275 bytes)
#  copying: dataset_image/691672427642761216.jpg  (124474 bytes)
#  copying: dataset_image/691673420254224384.jpg  (122491 bytes)
#  copying: dataset_image/691679925292564480.jpg  (60858 bytes)
#  copying: dataset_image/691688247794221056.jpg  (168798 bytes)
#  copying: dataset_image/691696897195511808.jpg  (77451 bytes)
#  copying: dataset_image/691699963584200705.jpg  (7766 bytes)
#  copying: dataset_image/691703222776524800.jpg  (26831 bytes)
#  copying: dataset_image/691712999518773248.jpg  (113526 bytes)
#  copying: dataset_image/691722157735436289.jpg  (90957 bytes)
#  copying: dataset_image/691725882860306432.jpg  (148435 bytes)
#  copying: dataset_image/691746648054222849.jpg  (82038 bytes)
#  copying: dataset_image/691750566133944321.jpg  (61208 bytes)
#  copying: dataset_image/691773240948232192.jpg  (15104 bytes)
#  copying: dataset_image/691777847061549058.jpg  (40447 bytes)
#  copying: dataset_image/691795297396199425.jpg  (67282 bytes)
#  copying: dataset_image/691813270139854849.jpg  (106120 bytes)
#  copying: dataset_image/691832111674855425.jpg  (181142 bytes)
#  copying: dataset_image/691843597424005122.jpg  (34173 bytes)
#  copying: dataset_image/691843915893325824.jpg  (196818 bytes)
#  copying: dataset_image/691870492240773120.jpg  (80265 bytes)
#  copying: dataset_image/691878605782171648.jpg  (115731 bytes)
#  copying: dataset_image/691915808591712257.jpg  (158177 bytes)
#  copying: dataset_image/691924656840925184.jpg  (81193 bytes)
#  copying: dataset_image/691936808263925762.jpg  (174857 bytes)
#  copying: dataset_image/691945974315487232.jpg  (159101 bytes)
#  copying: dataset_image/691996108738990080.jpg  (167130 bytes)
#  copying: dataset_image/692000086616887297.jpg  (26571 bytes)
#  copying: dataset_image/692013701772214272.jpg  (106139 bytes)
#  copying: dataset_image/692018768512466945.jpg  (65772 bytes)
#  copying: dataset_image/692069855823020032.jpg  (109575 bytes)
#  copying: dataset_image/692074628139716608.jpg  (88263 bytes)
#  copying: dataset_image/692076080933507072.jpg  (130591 bytes)
#  copying: dataset_image/692111882698776576.jpg  (58204 bytes)
#  copying: dataset_image/692117856696274944.jpg  (24458 bytes)
#  copying: dataset_image/692123983337132039.jpg  (27463 bytes)
#  copying: dataset_image/692129311487365120.jpg  (65642 bytes)
#  copying: dataset_image/692150765788463105.jpg  (77625 bytes)
#  copying: dataset_image/692203022550745088.jpg  (109196 bytes)
#  copying: dataset_image/692220407160672256.jpg  (56088 bytes)
#  copying: dataset_image/692234893082935297.jpg  (69890 bytes)
#  copying: dataset_image/692285316078669825.jpg  (82286 bytes)
#  copying: dataset_image/692304634870763521.jpg  (34781 bytes)
#  copying: dataset_image/692319239944982528.jpg  (92581 bytes)
#  copying: dataset_image/692330929432432640.jpg  (66487 bytes)
#  copying: dataset_image/692363616058617857.jpg  (41395 bytes)
#  copying: dataset_image/692377226956902400.jpg  (163089 bytes)
#  copying: dataset_image/692387490775306240.jpg  (112379 bytes)
#  copying: dataset_image/692419850942177280.jpg  (64038 bytes)
#  copying: dataset_image/692439296465313792.jpg  (83837 bytes)
#  copying: dataset_image/692462167568846849.jpg  (196915 bytes)
#  copying: dataset_image/692473402402152448.jpg  (36906 bytes)
#  copying: dataset_image/692490360384307204.jpg  (22209 bytes)
#  copying: dataset_image/692495868704989184.jpg  (51300 bytes)
#  copying: dataset_image/692499837191856132.jpg  (39562 bytes)
#  copying: dataset_image/692500389359411200.jpg  (51300 bytes)
#  copying: dataset_image/692502119027458053.jpg  (200842 bytes)
#  copying: dataset_image/692503893071257600.jpg  (37984 bytes)
#  copying: dataset_image/692512651696545793.jpg  (87087 bytes)
#  copying: dataset_image/692513161967226880.jpg  (112606 bytes)
#  copying: dataset_image/692513812499546113.jpg  (17331 bytes)
#  copying: dataset_image/692515586790666240.jpg  (37475 bytes)
#  copying: dataset_image/692544920238821376.jpg  (50444 bytes)
#  copying: dataset_image/692548416023453696.jpg  (103008 bytes)
#  copying: dataset_image/692551219542396929.jpg  (43136 bytes)
#  copying: dataset_image/692571966352429056.jpg  (98677 bytes)
#  copying: dataset_image/692580725133045760.jpg  (41686 bytes)
#  copying: dataset_image/692582838751768576.jpg  (33094 bytes)
#  copying: dataset_image/692584507786924032.jpg  (40369 bytes)
#  copying: dataset_image/692601830036094976.jpg  (52889 bytes)
#  copying: dataset_image/692665102412222464.jpg  (34225 bytes)
#  copying: dataset_image/692705556985937921.jpg  (69081 bytes)
#  copying: dataset_image/692769297639284736.jpg  (55481 bytes)
#  copying: dataset_image/692773093236981760.jpg  (70156 bytes)
#  copying: dataset_image/692773151357427714.jpg  (155982 bytes)
#  copying: dataset_image/692783192470917121.jpg  (47408 bytes)
#  copying: dataset_image/692789829722083332.jpg  (61846 bytes)
#  copying: dataset_image/692802991762485248.jpg  (135397 bytes)
#  copying: dataset_image/692803120913608705.jpg  (92097 bytes)
#  copying: dataset_image/692846957883076608.jpg  (126292 bytes)
#  copying: dataset_image/692856726823895041.jpg  (151264 bytes)
#  copying: dataset_image/693095258846957568.jpg  (31125 bytes)
#  copying: dataset_image/693147156799053825.jpg  (29135 bytes)
#  copying: dataset_image/693175231725359105.jpg  (137786 bytes)
#  copying: dataset_image/693187562681143296.jpg  (41345 bytes)
#  copying: dataset_image/693199180869844992.jpg  (213624 bytes)
#  copying: dataset_image/693199628536320000.jpg  (131281 bytes)
#  copying: dataset_image/693217080062005249.jpg  (115017 bytes)
#  copying: dataset_image/693227436452945920.jpg  (64852 bytes)
#  copying: dataset_image/693228941734096896.jpg  (191401 bytes)
#  copying: dataset_image/693277240780529664.jpg  (139282 bytes)
#  copying: dataset_image/693391070584029184.jpg  (30782 bytes)
#  copying: dataset_image/693396993675300864.jpg  (68674 bytes)
#  copying: dataset_image/693410085620461569.jpg  (160039 bytes)
#  copying: dataset_image/693412872232247301.jpg  (77378 bytes)
#  copying: dataset_image/693474636760256513.jpg  (97511 bytes)
#  copying: dataset_image/693489127044444161.jpg  (84206 bytes)
#  copying: dataset_image/693494117452480512.jpg  (61121 bytes)
#  copying: dataset_image/693502448628006913.jpg  (60127 bytes)
#  copying: dataset_image/693516785660903424.jpg  (149128 bytes)
#  copying: dataset_image/693529529214611457.jpg  (207223 bytes)
#  copying: dataset_image/693532666403123201.jpg  (48031 bytes)
#  copying: dataset_image/693582306959818753.jpg  (99345 bytes)
#  copying: dataset_image/693604697140232192.jpg  (62048 bytes)
#  copying: dataset_image/693610805342789632.jpg  (68325 bytes)
#  copying: dataset_image/693617999106801664.jpg  (126980 bytes)
#  copying: dataset_image/693623114639544320.jpg  (115728 bytes)
#  copying: dataset_image/693624570960543744.jpg  (31346 bytes)
#  copying: dataset_image/693624867384479744.jpg  (84410 bytes)
#  copying: dataset_image/693645157917417472.jpg  (23374 bytes)
#  copying: dataset_image/693667731565105152.jpg  (84572 bytes)
#  copying: dataset_image/693675164148469761.jpg  (42356 bytes)
#  copying: dataset_image/693701847878615040.jpg  (16955 bytes)
#  copying: dataset_image/693768761988517888.jpg  (221829 bytes)
#  copying: dataset_image/693800435895836672.jpg  (56944 bytes)
#  copying: dataset_image/693843390547529728.jpg  (124559 bytes)
#  copying: dataset_image/693852278223147008.jpg  (49107 bytes)
#  copying: dataset_image/693852643249233920.jpg  (34976 bytes)
#  copying: dataset_image/693897573422256128.jpg  (137598 bytes)
#  copying: dataset_image/693900021620740102.jpg  (90052 bytes)
#  copying: dataset_image/693914181704224769.jpg  (156471 bytes)
#  copying: dataset_image/693964832467357696.jpg  (119009 bytes)
#  copying: dataset_image/694004633929437185.jpg  (58282 bytes)
#  copying: dataset_image/694096163918598144.jpg  (122954 bytes)
#  copying: dataset_image/694168663902044161.jpg  (92646 bytes)
#  copying: dataset_image/694182433663483904.jpg  (130987 bytes)
#  copying: dataset_image/694188602092359680.jpg  (117460 bytes)
#  copying: dataset_image/694211941602963456.jpg  (12893 bytes)
#  copying: dataset_image/694228173471518725.jpg  (46458 bytes)
#  copying: dataset_image/694235473988980737.jpg  (81056 bytes)
#  copying: dataset_image/694252238659784709.jpg  (109180 bytes)
#  copying: dataset_image/694262101578227712.jpg  (146333 bytes)
#  copying: dataset_image/694266397023666181.jpg  (95968 bytes)
#  copying: dataset_image/694284789923229696.jpg  (68554 bytes)
#  copying: dataset_image/694329435881893888.jpg  (103110 bytes)
#  copying: dataset_image/694333173329563648.jpg  (36954 bytes)
#  copying: dataset_image/694364560564711424.jpg  (57355 bytes)
#  copying: dataset_image/694378345413251073.jpg  (94142 bytes)
#  copying: dataset_image/694383837065801728.jpg  (9584 bytes)
#  copying: dataset_image/694415308770021376.jpg  (61714 bytes)
#  copying: dataset_image/694514029121949696.jpg  (39255 bytes)
#  copying: dataset_image/694514328603459585.jpg  (63750 bytes)
#  copying: dataset_image/694528109043822592.jpg  (85738 bytes)
#  copying: dataset_image/694536364596056065.jpg  (65878 bytes)
#  copying: dataset_image/694548759049535488.jpg  (44940 bytes)
#  copying: dataset_image/694551992539045888.jpg  (52821 bytes)
#  copying: dataset_image/694554793918992384.jpg  (136645 bytes)
#  copying: dataset_image/694569200032022528.jpg  (116432 bytes)
#  copying: dataset_image/694578847732371456.jpg  (66976 bytes)
#  copying: dataset_image/694582891850915840.jpg  (64916 bytes)
#  copying: dataset_image/694584307655012358.jpg  (29825 bytes)
#  copying: dataset_image/694608795599781889.jpg  (26444 bytes)
#  copying: dataset_image/694631116221739008.jpg  (125170 bytes)
#  copying: dataset_image/694633061695119360.jpg  (52236 bytes)
#  copying: dataset_image/694643759976415232.jpg  (184731 bytes)
#  copying: dataset_image/694651236981870597.jpg  (37473 bytes)
#  copying: dataset_image/694653679664640002.jpg  (146587 bytes)
#  copying: dataset_image/694660191288168449.jpg  (49917 bytes)
#  copying: dataset_image/694660745980608512.jpg  (99149 bytes)
#  copying: dataset_image/694661584761835520.jpg  (51052 bytes)
#  copying: dataset_image/694666572871385089.jpg  (151881 bytes)
#  copying: dataset_image/694670743515348993.jpg  (65142 bytes)
#  copying: dataset_image/694671399730819072.jpg  (93990 bytes)
#  copying: dataset_image/694692998924406784.jpg  (34888 bytes)
#  copying: dataset_image/694722188285480960.jpg  (24505 bytes)
#  copying: dataset_image/694792110080430080.jpg  (41986 bytes)
#  copying: dataset_image/694814850434732032.jpg  (95698 bytes)
#  copying: dataset_image/694846210612469760.jpg  (28796 bytes)
#  copying: dataset_image/694865570173288448.jpg  (68524 bytes)
#  copying: dataset_image/694869260003336194.jpg  (41565 bytes)
#  copying: dataset_image/694889707122122752.jpg  (105427 bytes)
#  copying: dataset_image/694893939556491264.jpg  (57929 bytes)
#  copying: dataset_image/694937518395957249.jpg  (46315 bytes)
#  copying: dataset_image/694954515599093761.jpg  (63306 bytes)
#  copying: dataset_image/694964475850579969.jpg  (162094 bytes)
#  copying: dataset_image/694968245112086528.jpg  (117294 bytes)
#  copying: dataset_image/695029150239870976.jpg  (64484 bytes)
#  copying: dataset_image/695057844173836289.jpg  (58013 bytes)
#  copying: dataset_image/695058298496688128.jpg  (124756 bytes)
#  copying: dataset_image/695064616955699200.jpg  (144553 bytes)
#  copying: dataset_image/695074217646125057.jpg  (48422 bytes)
#  copying: dataset_image/695108825200795648.jpg  (35396 bytes)
#  copying: dataset_image/695187209746583552.jpg  (19185 bytes)
#  copying: dataset_image/695240749332484096.jpg  (40606 bytes)
#  copying: dataset_image/695262106615156736.jpg  (84315 bytes)
#  copying: dataset_image/695293983761764353.jpg  (100534 bytes)
#  copying: dataset_image/695308547685490689.jpg  (41205 bytes)
#  copying: dataset_image/695312175066435585.jpg  (104792 bytes)
#  copying: dataset_image/695337574374637568.jpg  (70994 bytes)
#  copying: dataset_image/695339269645152259.jpg  (15107 bytes)
#  copying: dataset_image/695371336038756352.jpg  (237930 bytes)
#  copying: dataset_image/695387931108769792.jpg  (41535 bytes)
#  copying: dataset_image/695392140227059712.jpg  (22916 bytes)
#  copying: dataset_image/695403013502951424.jpg  (85613 bytes)
#  copying: dataset_image/695408460888846336.jpg  (52429 bytes)
#  copying: dataset_image/695416820098953219.jpg  (67398 bytes)
#  copying: dataset_image/695427831497564161.jpg  (103150 bytes)
#  copying: dataset_image/695623054173433857.jpg  (121826 bytes)
#  copying: dataset_image/695623570341367808.jpg  (145227 bytes)
#  copying: dataset_image/695643893866504192.jpg  (163577 bytes)
#  copying: dataset_image/695656159395586048.jpg  (96892 bytes)
#  copying: dataset_image/695661951490224128.jpg  (175242 bytes)
#  copying: dataset_image/695678212031062017.jpg  (71247 bytes)
#  copying: dataset_image/695681736437411840.jpg  (83169 bytes)
#  copying: dataset_image/695702932512120832.jpg  (198783 bytes)
#  copying: dataset_image/695712625984999424.jpg  (153063 bytes)
#  copying: dataset_image/695714852241670145.jpg  (45968 bytes)
#  copying: dataset_image/695718199866761218.jpg  (127990 bytes)
#  copying: dataset_image/695718747844116481.jpg  (38665 bytes)
#  copying: dataset_image/695723997888118785.jpg  (76956 bytes)
#  copying: dataset_image/695730406667190272.jpg  (65225 bytes)
#  copying: dataset_image/695739110342967296.jpg  (44894 bytes)
#  copying: dataset_image/695776998187212800.jpg  (21427 bytes)
#  copying: dataset_image/695792868053614592.jpg  (7154 bytes)
#  copying: dataset_image/695799607188545536.jpg  (67519 bytes)
#  copying: dataset_image/695803007967973376.jpg  (22281 bytes)
#  copying: dataset_image/695829439142301696.jpg  (30792 bytes)
#  copying: dataset_image/695840050144149505.jpg  (191234 bytes)
#  copying: dataset_image/695899457439707136.jpg  (4398 bytes)
#  copying: dataset_image/696008220578414596.jpg  (111527 bytes)
#  copying: dataset_image/696013118451929088.jpg  (142088 bytes)
#  copying: dataset_image/696016995611975681.jpg  (46022 bytes)
#  copying: dataset_image/696024927170797568.jpg  (49255 bytes)
#  copying: dataset_image/696044029234950144.jpg  (54770 bytes)
#  copying: dataset_image/696059592640430081.jpg  (38025 bytes)
#  copying: dataset_image/696063874693537796.jpg  (293358 bytes)
#  copying: dataset_image/696095346913517569.jpg  (146880 bytes)
#  copying: dataset_image/696097163537948672.jpg  (37675 bytes)
#  copying: dataset_image/696098184230141952.jpg  (144981 bytes)
#  copying: dataset_image/696098754286460928.jpg  (43044 bytes)
#  copying: dataset_image/696105771960930304.jpg  (210235 bytes)
#  copying: dataset_image/696129734401507329.jpg  (37620 bytes)
#  copying: dataset_image/696130174245609472.jpg  (112839 bytes)
#  copying: dataset_image/696142189076680708.jpg  (33971 bytes)
#  copying: dataset_image/696181210230423552.jpg  (38105 bytes)
#  copying: dataset_image/696184605234241536.jpg  (69244 bytes)
#  copying: dataset_image/696232777373630464.jpg  (65119 bytes)
#  copying: dataset_image/696248977847644161.jpg  (130041 bytes)
#  copying: dataset_image/696293252878569472.jpg  (13306 bytes)
#  copying: dataset_image/696313514227539968.jpg  (69081 bytes)
#  copying: dataset_image/696337814485598208.jpg  (205405 bytes)
#  copying: dataset_image/696349373945384960.jpg  (29937 bytes)
#  copying: dataset_image/696385065585135616.jpg  (75615 bytes)
#  copying: dataset_image/696389385328160768.jpg  (34976 bytes)
#  copying: dataset_image/696395273447329792.jpg  (55900 bytes)
#  copying: dataset_image/696403329749008384.jpg  (107306 bytes)
#  copying: dataset_image/696410538981494790.jpg  (32085 bytes)
#  copying: dataset_image/696422013863211008.jpg  (27023 bytes)
#  copying: dataset_image/696440520269107200.jpg  (79012 bytes)
#  copying: dataset_image/696441372379783169.jpg  (13482 bytes)
#  copying: dataset_image/696451098098274304.jpg  (124309 bytes)
# ...
#  copying: dataset_image/937718866255450113.jpg  (29868 bytes)
#  copying: dataset_image/937726471568789506.jpg  (70725 bytes)
#  copying: dataset_image/937726782597349376.jpg  (70088 bytes)
#  copying: dataset_image/937730614085783553.jpg  (46364 bytes)
#  copying: dataset_image/937730846731235340.jpg  (218969 bytes)
#  copying: dataset_image/937745466296623107.jpg  (92536 bytes)
#  copying: dataset_image/937747831523299330.jpg  (83090 bytes)
#  copying: dataset_image/937753107290836992.jpg  (63962 bytes)
#  copying: dataset_image/937773431348658177.jpg  (227070 bytes)
#  copying: dataset_image/937774927964282880.jpg  (134164 bytes)
#  copying: dataset_image/937776053782753283.jpg  (205792 bytes)
#  copying: dataset_image/937787096768671744.jpg  (117729 bytes)
#  copying: dataset_image/937797749566791680.jpg  (219190 bytes)
#  copying: dataset_image/937826427877183488.jpg  (95095 bytes)
#  copying: dataset_image/937832479205068800.jpg  (190458 bytes)
#  copying: dataset_image/937836727007436800.jpg  (48245 bytes)
#  copying: dataset_image/937838765720162304.jpg  (15238 bytes)
#  copying: dataset_image/937840549486387200.jpg  (39797 bytes)
#  copying: dataset_image/937840768861040642.jpg  (160619 bytes)
#  copying: dataset_image/937873859365298176.jpg  (42014 bytes)
#  copying: dataset_image/937879622255030275.jpg  (30453 bytes)
#  copying: dataset_image/937887792658550785.jpg  (40819 bytes)
#  copying: dataset_image/937914397057466369.jpg  (75662 bytes)
#  copying: dataset_image/937915733828235265.jpg  (122268 bytes)
#  copying: dataset_image/937936497365233665.jpg  (139138 bytes)
#  copying: dataset_image/937943250777673728.jpg  (52920 bytes)
#  copying: dataset_image/937949267234361344.jpg  (124701 bytes)
#  copying: dataset_image/937962910218821632.jpg  (119529 bytes)
#  copying: dataset_image/937963736932818945.jpg  (84078 bytes)
#  copying: dataset_image/937989340864507904.jpg  (135937 bytes)
#  copying: dataset_image/937995353810440192.jpg  (347114 bytes)
#  copying: dataset_image/938032586705768449.jpg  (157643 bytes)
#  copying: dataset_image/938045090244780032.jpg  (97779 bytes)
#  copying: dataset_image/938050598489829376.jpg  (112693 bytes)
#  copying: dataset_image/938067850002141189.jpg  (58030 bytes)
#  copying: dataset_image/938127718213808128.jpg  (84382 bytes)
#  copying: dataset_image/938133508865839107.jpg  (84503 bytes)
#  copying: dataset_image/938154545032593409.jpg  (209293 bytes)
#  copying: dataset_image/938155806209458176.jpg  (44884 bytes)
#  copying: dataset_image/938166504662614016.jpg  (16519 bytes)
#  copying: dataset_image/938167363526184963.jpg  (126593 bytes)
#  copying: dataset_image/938181873720635392.jpg  (21825 bytes)
#  copying: dataset_image/938206187916443648.jpg  (236391 bytes)
#  copying: dataset_image/938214865524658176.jpg  (131315 bytes)
#  copying: dataset_image/938217152422825984.jpg  (179067 bytes)
#  copying: dataset_image/938227063156330498.jpg  (103933 bytes)
#  copying: dataset_image/938336915425603584.jpg  (8091 bytes)
#  copying: dataset_image/938342400300388352.jpg  (197577 bytes)
#  copying: dataset_image/938366385935212546.jpg  (12397 bytes)
#  copying: dataset_image/938405524751683586.jpg  (114889 bytes)
#  copying: dataset_image/938413706009911296.jpg  (240327 bytes)
#  copying: dataset_image/938414903324442625.jpg  (81509 bytes)
#  copying: dataset_image/938422669627752451.jpg  (84994 bytes)
#  copying: dataset_image/938424698551046144.jpg  (260954 bytes)
#  copying: dataset_image/938434324101193731.jpg  (134816 bytes)
#  copying: dataset_image/938451385045184512.jpg  (17885 bytes)
#  copying: dataset_image/938456730370965504.jpg  (140901 bytes)
#  copying: dataset_image/938479926038147075.jpg  (142529 bytes)
#  copying: dataset_image/938486277040754689.jpg  (129187 bytes)
#  copying: dataset_image/938502570196324352.jpg  (59227 bytes)
#  copying: dataset_image/938516709685723141.jpg  (166794 bytes)
#  copying: dataset_image/938551090114678790.jpg  (130474 bytes)
#  copying: dataset_image/938567465336016897.jpg  (201924 bytes)
#  copying: dataset_image/938604504920059910.jpg  (23530 bytes)
#  copying: dataset_image/938616699087044608.jpg  (72477 bytes)
#  copying: dataset_image/938623894029815808.jpg  (89687 bytes)
#  copying: dataset_image/938626989094666240.jpg  (107155 bytes)
#  copying: dataset_image/938669685960298496.jpg  (102589 bytes)
#  copying: dataset_image/938669924347625472.jpg  (72222 bytes)
#  copying: dataset_image/938675193135771648.jpg  (67774 bytes)
#  copying: dataset_image/938679478556831745.jpg  (154502 bytes)
#  copying: dataset_image/938682775325966336.jpg  (114000 bytes)
#  copying: dataset_image/938687022511939584.jpg  (33365 bytes)
#  copying: dataset_image/938714961664204800.jpg  (154013 bytes)
#  copying: dataset_image/938715460886863872.jpg  (23893 bytes)
#  copying: dataset_image/938716060576047105.jpg  (59026 bytes)
#  copying: dataset_image/938733392555855873.jpg  (26875 bytes)
#  copying: dataset_image/938738892764835846.jpg  (40111 bytes)
#  copying: dataset_image/938739869202857985.jpg  (138068 bytes)
#  copying: dataset_image/938755554217832448.jpg  (16095 bytes)
#  copying: dataset_image/938770071131889665.jpg  (99782 bytes)
#  copying: dataset_image/938795164243546113.jpg  (70115 bytes)
#  copying: dataset_image/938796305161351168.jpg  (41032 bytes)
#  copying: dataset_image/938796493875634176.jpg  (76573 bytes)
#  copying: dataset_image/938800275946639360.jpg  (64252 bytes)
#  copying: dataset_image/938813110806351873.jpg  (135774 bytes)
#  copying: dataset_image/938819144396423168.jpg  (90298 bytes)
#  copying: dataset_image/938822920339623937.jpg  (64578 bytes)
#  copying: dataset_image/938830482170671105.jpg  (86227 bytes)
#  copying: dataset_image/938838173291081729.jpg  (55497 bytes)
#  copying: dataset_image/938854362490605569.jpg  (55143 bytes)
#  copying: dataset_image/938858716358676480.jpg  (23445 bytes)
#  copying: dataset_image/938868490189946880.jpg  (113234 bytes)
#  copying: dataset_image/938873673645047808.jpg  (11421 bytes)
#  copying: dataset_image/938888425100529666.jpg  (44139 bytes)
#  copying: dataset_image/938897664111935499.jpg  (111104 bytes)
#  copying: dataset_image/938899544682704897.jpg  (111180 bytes)
#  copying: dataset_image/938901693768626176.jpg  (46741 bytes)
#  copying: dataset_image/938950575064080384.jpg  (91178 bytes)
#  copying: dataset_image/939010628236165120.jpg  (56339 bytes)
#  copying: dataset_image/939023118789513216.jpg  (178059 bytes)
#  copying: dataset_image/939034309930954752.jpg  (115703 bytes)
#  copying: dataset_image/939049409559650305.jpg  (60705 bytes)
#  copying: dataset_image/939052922301763585.jpg  (153940 bytes)
#  copying: dataset_image/939053184999292928.jpg  (86750 bytes)
#  copying: dataset_image/939056967275782145.jpg  (83278 bytes)
#  copying: dataset_image/939083875715899393.jpg  (52185 bytes)
#  copying: dataset_image/939091959058010112.jpg  (76951 bytes)
#  copying: dataset_image/939117366121762816.jpg  (79232 bytes)
#  copying: dataset_image/939124019009327105.jpg  (159335 bytes)
#  copying: dataset_image/939132557270151168.jpg  (166915 bytes)
#  copying: dataset_image/939173778709499904.jpg  (20588 bytes)
#  copying: dataset_image/939206957440778240.jpg  (102550 bytes)
#  copying: dataset_image/939239357755600897.jpg  (87738 bytes)
#  copying: dataset_image/939249169859874816.jpg  (80263 bytes)
#  copying: dataset_image/939289853354639360.jpg  (86204 bytes)
#  copying: dataset_image/939291001155338240.jpg  (81730 bytes)
#  copying: dataset_image/939294618272911360.jpg  (113758 bytes)
#  copying: dataset_image/939303313907970049.jpg  (45630 bytes)
#  copying: dataset_image/939319527938117633.jpg  (150655 bytes)
#  copying: dataset_image/939320936670605317.jpg  (161308 bytes)
#  copying: dataset_image/939327936066400257.jpg  (93952 bytes)
#  copying: dataset_image/939364835757830145.jpg  (59129 bytes)
#  copying: dataset_image/939370614074281989.jpg  (81954 bytes)
#  copying: dataset_image/939414381007314944.jpg  (36167 bytes)
#  copying: dataset_image/939428289202057216.jpg  (50717 bytes)
#  copying: dataset_image/939474646092734469.jpg  (100830 bytes)
#  copying: dataset_image/939505813273698305.jpg  (187404 bytes)
#  copying: dataset_image/939508723189534720.jpg  (22583 bytes)
#  copying: dataset_image/939526417695481856.jpg  (44387 bytes)
#  copying: dataset_image/939542895362584577.jpg  (83952 bytes)
#  copying: dataset_image/939543849151664128.jpg  (31323 bytes)
#  copying: dataset_image/939543876175511553.jpg  (71369 bytes)
#  copying: dataset_image/939562850078556160.jpg  (288214 bytes)
#  copying: dataset_image/939591306392821760.jpg  (248806 bytes)
#  copying: dataset_image/939626966214311936.jpg  (80803 bytes)
#  copying: dataset_image/939642067378110464.jpg  (100879 bytes)
#  copying: dataset_image/939645852255002624.jpg  (215405 bytes)
#  copying: dataset_image/939662601759350785.jpg  (62204 bytes)
#  copying: dataset_image/939671798676905984.jpg  (51810 bytes)
#  copying: dataset_image/939714200456318981.jpg  (75215 bytes)
#  copying: dataset_image/939728260946067456.jpg  (27178 bytes)
#  copying: dataset_image/939747349009747968.jpg  (207150 bytes)
#  copying: dataset_image/939751204808097792.jpg  (8106 bytes)
#  copying: dataset_image/939769831481516032.jpg  (8072 bytes)
#  copying: dataset_image/939796607889035264.jpg  (133430 bytes)
#  copying: dataset_image/939879413839204352.jpg  (102024 bytes)
#  copying: dataset_image/939883533904023553.jpg  (102808 bytes)
#  copying: dataset_image/939885832667848705.jpg  (85837 bytes)
#  copying: dataset_image/939889481863303168.jpg  (92166 bytes)
#  copying: dataset_image/939944627297124353.jpg  (55378 bytes)
#  copying: dataset_image/939944779739213824.jpg  (24576 bytes)
#  copying: dataset_image/939953242129170433.jpg  (68819 bytes)
#  copying: dataset_image/940002603911602182.jpg  (52400 bytes)
#  copying: dataset_image/940009742826647552.jpg  (123229 bytes)
#  copying: dataset_image/940133052943962113.jpg  (178237 bytes)
#  copying: dataset_image/940142308556541954.jpg  (22459 bytes)
#  copying: dataset_image/940183881130610688.jpg  (57982 bytes)
#  copying: dataset_image/940191839117828096.jpg  (175141 bytes)
#  copying: dataset_image/940202475184885760.jpg  (419523 bytes)
#  copying: dataset_image/940221931659313152.jpg  (164194 bytes)
#  copying: dataset_image/940227257116844032.jpg  (93664 bytes)
#  copying: dataset_image/940241431616282625.jpg  (132801 bytes)
#  copying: dataset_image/940264212441567234.jpg  (108046 bytes)
#  copying: dataset_image/940264356675284993.jpg  (130144 bytes)
#  copying: dataset_image/940265745476284416.jpg  (20829 bytes)
#  copying: dataset_image/940308883695861761.jpg  (231413 bytes)
#  copying: dataset_image/940317389794762752.jpg  (70456 bytes)
#  copying: dataset_image/940344973005869057.jpg  (141027 bytes)
#  copying: dataset_image/940346962234130432.jpg  (16025 bytes)
#  copying: dataset_image/940354305470722049.jpg  (262614 bytes)
#  copying: dataset_image/940357305119408128.jpg  (3052 bytes)
#  copying: dataset_image/940687407715774465.jpg  (55378 bytes)
#  copying: dataset_image/940690391078260737.jpg  (50510 bytes)
#  copying: dataset_image/940702461714714624.jpg  (147684 bytes)
#  copying: dataset_image/940704208889638912.jpg  (214537 bytes)
#  copying: dataset_image/940716720104329218.jpg  (33530 bytes)
#  copying: dataset_image/940985374565953537.jpg  (140011 bytes)
#  copying: dataset_image/941003843675942913.jpg  (159566 bytes)
#  copying: dataset_image/941028485794955264.jpg  (47167 bytes)
#  copying: dataset_image/941062957185744896.jpg  (30608 bytes)
#  copying: dataset_image/941083385396695041.jpg  (40755 bytes)
#  copying: dataset_image/941430864038174720.jpg  (79808 bytes)
#  copying: dataset_image/941434627436302336.jpg  (72669 bytes)
#  copying: dataset_image/941443078115774464.jpg  (28122 bytes)
#  copying: dataset_image/941756290635665408.jpg  (39659 bytes)
#  copying: dataset_image/941783087607963648.jpg  (296196 bytes)
#  copying: dataset_image/941799950345801729.jpg  (207139 bytes)
#  copying: dataset_image/941806906330570753.jpg  (65077 bytes)
#  copying: dataset_image/942788465657180160.jpg  (31587 bytes)
#  copying: dataset_image/942793570381062144.jpg  (29279 bytes)
#  copying: dataset_image/942798024115458048.jpg  (61193 bytes)
#  copying: dataset_image/942805546993881088.jpg  (71535 bytes)
#  copying: dataset_image/942825892115464192.jpg  (100773 bytes)
#  copying: dataset_image/942842015456354305.jpg  (221388 bytes)
#  copying: dataset_image/942863777388814337.jpg  (95452 bytes)
#  copying: dataset_image/942870821135159296.jpg  (33009 bytes)
#  copying: dataset_image/942885656782614528.jpg  (267437 bytes)
#  copying: dataset_image/942901356020584448.jpg  (61315 bytes)
#  copying: dataset_image/943217660816515079.jpg  (94146 bytes)
#  copying: dataset_image/943239368021626880.jpg  (97404 bytes)
#  copying: dataset_image/943260773618536451.jpg  (74175 bytes)
#  copying: dataset_image/943269321517576192.jpg  (258211 bytes)
#  copying: dataset_image/943956425251975170.jpg  (35222 bytes)
#  copying: dataset_image/943964134248472576.jpg  (41428 bytes)
#  copying: dataset_image/943979023063019521.jpg  (89917 bytes)
#  copying: dataset_image/943979929468899328.jpg  (134136 bytes)
#  copying: dataset_image/943981475053080576.jpg  (128616 bytes)
#  copying: dataset_image/943984761588117504.jpg  (316257 bytes)
#  copying: dataset_image/944611826599329792.jpg  (13793 bytes)
#  copying: dataset_image/944616584403963905.jpg  (127474 bytes)
#  copying: dataset_image/944616665798664193.jpg  (23573 bytes)
#  copying: dataset_image/944638134247153669.jpg  (84767 bytes)
#  copying: dataset_image/944644685766774784.jpg  (14830 bytes)
#  copying: dataset_image/944662262563909636.jpg  (109041 bytes)
#  copying: dataset_image/944684675724926977.jpg  (151886 bytes)
#  copying: dataset_image/944688430902104065.jpg  (52769 bytes)
#  copying: dataset_image/944706094127083520.jpg  (89813 bytes)
#  copying: dataset_image/944717549052334080.jpg  (200475 bytes)
#  copying: dataset_image/945431876965163008.jpg  (223868 bytes)
#  copying: dataset_image/945434649479622656.jpg  (174461 bytes)
#  copying: dataset_image/945436937749348352.jpg  (55378 bytes)
#  copying: dataset_image/945776585222836224.jpg  (18508 bytes)
#  copying: dataset_image/945778202315763712.jpg  (37728 bytes)
#  copying: dataset_image/946155114238173185.jpg  (17646 bytes)
#  copying: dataset_image/946156500396814336.jpg  (53143 bytes)
#  copying: dataset_image/946161659646742528.jpg  (111712 bytes)
#  copying: dataset_image/946496936248569858.jpg  (10623 bytes)
#  copying: dataset_image/946501176010395651.jpg  (42549 bytes)
#  copying: dataset_image/946501285167206401.jpg  (119100 bytes)
#  copying: dataset_image/946524645032976385.jpg  (89579 bytes)
# Central Directory found...
# EOCDR found ( 4 459858515)...
# UnZip 6.00 of 20 April 2009, by Info-ZIP.  Maintained by C. Spieler.  Send
# bug reports using http://www.info-zip.org/zip-bug.html; see README for details.
#
# Usage: unzip [-Z] [-opts[modifiers]] file[.zip] [list] [-x xlist] [-d exdir]
#   Default action is to extract files in list, except those in xlist, to exdir;
#   file[.zip] may be a wildcard.  -Z => ZipInfo mode ("unzip -Z" for usage).
#
#   -p  extract files to pipe, no messages     -l  list files (short format)
#   -f  freshen existing files, create none    -t  test compressed archive data
#   -u  update files, create if necessary      -z  display archive comment only
#   -v  list verbosely/show version info       -T  timestamp archive to latest
#   -x  exclude files that follow (in xlist)   -d  extract files into exdir
# modifiers:
#   -n  never overwrite existing files         -q  quiet mode (-qq => quieter)
#   -o  overwrite files WITHOUT prompting      -a  auto-convert any text files
#   -j  junk paths (do not make directories)   -aa treat ALL files as text
#   -C  match filenames case-insensitively     -L  make (some) names lowercase
#   -X  restore UID/GID info                   -V  retain VMS version numbers
#   -K  keep setuid/setgid/tacky permissions   -M  pipe through "more" pager
# See "unzip -hh" or unzip.txt for more help.  Examples:
#   unzip data1 -x joe   => extract all files except joe from zipfile data1.zip
#   unzip -p foo | more  => send contents of foo.zip via pipe into program more
#   unzip -fo foo ReadMe => quietly replace existing ReadMe if archive file newer

# %%
# Create subdirectories
import os
import shutil

train_dir = '/Users/albert/Documents/CSE8813_DLT/Sarcasm-Detection-hierarchical_fusion_model/image_data/train/'
val_dir = '/Users/albert/Documents/CSE8813_DLT/Sarcasm-Detection-hierarchical_fusion_model/image_data/val/'
test_dir = '/Users/albert/Documents/CSE8813_DLT/Sarcasm-Detection-hierarchical_fusion_model/image_data/test/'

os.mkdir(train_dir)
os.mkdir(val_dir)
os.mkdir(test_dir)

# %%
missing_ids = []

for id in df_train['ID']:
    img_path = '/Users/albert/Documents/CSE8813_DLT/Sarcasm-Detection-hierarchical_fusion_model/image_data/{}.jpg'.format(id)
    #img_path = 'dataset_image/{}.jpg'.format(id)
    if os.path.isfile(img_path):
        #shutil.move(img_path, '/Users/albert/Documents/CSE8813_DLT/Sarcasm-Detection-hierarchical_fusion_model/image_data/train/{}.jpg'.format(id))

      shutil.move(img_path, '/Users/albert/Documents/CSE8813_DLT/Sarcasm-Detection-hierarchical_fusion_model/image_data/train/{}.jpg'.format(id))
    else:
        missing_ids.append(id)

# %%
len(missing_ids)
# Out:
# 9224

# %%
df_train = df_train[~df_train['ID'].isin(missing_ids)]
df_train.shape
# Out:
# (19816, 3)

# %%
for id in df_val['ID']:
    img_path = '/Users/albert/Documents/CSE8813_DLT/Sarcasm-Detection-hierarchical_fusion_model/image_data/{}.jpg'.format(id)
    if os.path.isfile(img_path):
      shutil.move(img_path, '/Users/albert/Documents/CSE8813_DLT/Sarcasm-Detection-hierarchical_fusion_model/image_data/val/{}.jpg'.format(id))

# %%
for id in df_test['ID']:
    img_path = '/Users/albert/Documents/CSE8813_DLT/Sarcasm-Detection-hierarchical_fusion_model/image_data/{}.jpg'.format(id)
    if os.path.isfile(img_path):
      shutil.move(img_path, '/Users/albert/Documents/CSE8813_DLT/Sarcasm-Detection-hierarchical_fusion_model/image_data/test/{}.jpg'.format(id))

# %%
os.mkdir('/Users/albert/Documents/CSE8813_DLT/Sarcasm-Detection-hierarchical_fusion_model/image_data/train/sarc/')
os.mkdir('/Users/albert/Documents/CSE8813_DLT/Sarcasm-Detection-hierarchical_fusion_model/image_data/train/non-sarc/')
os.mkdir('/Users/albert/Documents/CSE8813_DLT/Sarcasm-Detection-hierarchical_fusion_model/image_data/val/sarc/')
os.mkdir('/Users/albert/Documents/CSE8813_DLT/Sarcasm-Detection-hierarchical_fusion_model/image_data/val/non-sarc/')
os.mkdir('/Users/albert/Documents/CSE8813_DLT/Sarcasm-Detection-hierarchical_fusion_model/image_data/test/sarc/')
os.mkdir('/Users/albert/Documents/CSE8813_DLT/Sarcasm-Detection-hierarchical_fusion_model/image_data/test/non-sarc/')

# %%
class_foldername = {
    True: 'sarc',
    False: 'non-sarc'
}

# %%
# Move images to subfolders
for id,label in zip(df_train['ID'], df_train['Sarcastic']):
    shutil.move('/Users/albert/Documents/CSE8813_DLT/Sarcasm-Detection-hierarchical_fusion_model/image_data/train/{}.jpg'.format(id), '/Users/albert/Documents/CSE8813_DLT/Sarcasm-Detection-hierarchical_fusion_model/image_data/train/{}/{}.jpg'.format(class_foldername[label], id))

# %%
# Move images to subfolders
for id,label in zip(df_val['ID'], df_val['Sarcastic']):
    shutil.move('/Users/albert/Documents/CSE8813_DLT/Sarcasm-Detection-hierarchical_fusion_model/image_data/val/{}.jpg'.format(id), '/Users/albert/Documents/CSE8813_DLT/Sarcasm-Detection-hierarchical_fusion_model/image_data/val/{}/{}.jpg'.format(class_foldername[label], id))

# %%
normalize = transforms.Normalize(mean=[0.485, 0.456, 0.406],
                                 std=[0.229, 0.224, 0.225])

data_transforms = {
    'train':
    transforms.Compose([
        transforms.Resize((224,224)),
        transforms.RandomAffine(0, shear=10, scale=(0.8,1.2)),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        normalize
    ]),
    'validation':
    transforms.Compose([
        transforms.Resize((224,224)),
        transforms.ToTensor(),
        normalize
    ]),
}

image_datasets = {
    'train': 
    datasets.ImageFolder('/Users/albert/Documents/CSE8813_DLT/Sarcasm-Detection-hierarchical_fusion_model/image_data/train', data_transforms['train']),
    'validation': 
    datasets.ImageFolder('/Users/albert/Documents/CSE8813_DLT/Sarcasm-Detection-hierarchical_fusion_model/image_data/val', data_transforms['validation'])
}

image_dataloaders = {
    'train':
    torch.utils.data.DataLoader(image_datasets['train'],
                                batch_size=64,
                                shuffle=True),
    'validation':
    torch.utils.data.DataLoader(image_datasets['validation'],
                                batch_size=64,
                                shuffle=False)
}

# %%
# dataloader for txt data
from transformers import AutoModel, AutoTokenizer

from sklearn.utils import shuffle
from transformers import (get_linear_schedule_with_warmup,AdamW,AutoModel, AutoTokenizer,
                            AutoModelForSequenceClassification)
from torch.utils.data import (TensorDataset,DataLoader,
                             RandomSampler, SequentialSampler, Dataset)


train_df = shuffle(df_train, random_state=42)
valid_df = shuffle(df_val, random_state=42)
test_df = shuffle(df_test, random_state=42)

# %%
bertweet = AutoModel.from_pretrained("vinai/bertweet-base")
tokenizer = AutoTokenizer.from_pretrained("vinai/bertweet-base", use_fast=False)

text_model = AutoModelForSequenceClassification.from_pretrained(
    "vinai/bertweet-base",
        num_labels = 2,  
        output_attentions = False, 
        output_hidden_states = True,
    )
# Out:
# Some weights of the model checkpoint at vinai/bertweet-base were not used when initializing RobertaModel: ['lm_head.layer_norm.bias', 'lm_head.dense.bias', 'lm_head.decoder.bias', 'lm_head.layer_norm.weight', 'lm_head.bias', 'lm_head.dense.weight', 'lm_head.decoder.weight']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# Some weights of the model checkpoint at vinai/bertweet-base were not used when initializing RobertaForSequenceClassification: ['lm_head.layer_norm.bias', 'roberta.pooler.dense.weight', 'lm_head.dense.bias', 'lm_head.decoder.bias', 'lm_head.layer_norm.weight', 'lm_head.bias', 'roberta.pooler.dense.bias', 'lm_head.dense.weight', 'lm_head.decoder.weight']
# - This IS expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaForSequenceClassification were not initialized from the model checkpoint at vinai/bertweet-base and are newly initialized: ['classifier.dense.weight', 'classifier.out_proj.bias', 'classifier.dense.bias', 'classifier.out_proj.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
def bert_encode(df, tokenizer):
    input_ids = []
    attention_masks = []
    # print(df)
    for sent,obj in zip(df[['Text']].values,df["object"].values):
        sent = sent.item()
        #print("sent")
        #print(sent)
        #obj = obj.item()
        #print(obj)
        sent = obj+sent
        print("combined")
        print(sent)
        encoded_dict = tokenizer.encode_plus(
                            sent,                      
                            add_special_tokens = True, 
                            max_length = 128,           
                            pad_to_max_length = True,
                            truncation = True,
                            return_attention_mask = True,   
                            return_tensors = 'pt',    
                    )
           
        input_ids.append(encoded_dict['input_ids'])
        attention_masks.append(encoded_dict['attention_mask'])
    input_ids = torch.cat(input_ids, dim=0)
    attention_masks = torch.cat(attention_masks, dim=0)

    inputs = {
    'input_word_ids': input_ids,
    'input_mask': attention_masks}

    return inputs

# %%
from torch.utils.data import (TensorDataset,DataLoader,
                             RandomSampler, SequentialSampler, Dataset)

def prepare_dataloaders(train_df,test_df,batch_size=64):
    # Load the AutoTokenizer with a normalization mode if the input Tweet is raw
    
    tokenizer = AutoTokenizer.from_pretrained("vinai/bertweet-base", use_fast=False, normalization=True)
    
    tweet_train = bert_encode(train_df, tokenizer)
    tweet_train_labels = train_df['Sarcastic'].astype(int)
    
    tweet_test = bert_encode(test_df, tokenizer)

    input_ids, attention_masks = tweet_train.values()
    labels = torch.tensor(tweet_train_labels.values)
    train_dataset = TensorDataset(input_ids, attention_masks, labels)

    
    input_ids, attention_masks = tweet_test.values()
    test_dataset = TensorDataset(input_ids, attention_masks)

    
    train_dataloader = DataLoader(
                train_dataset,
                sampler = RandomSampler(train_dataset), 
                batch_size = batch_size 
            )


    test_dataloader = DataLoader(
                test_dataset, 
                sampler = SequentialSampler(test_dataset), 
                batch_size = batch_size
            )
    return train_dataloader, test_dataloader

# %%
#text_train_dataloader,text_test_dataloader = prepare_dataloaders(train_df, test_df)
#_,text_val_dataloader = prepare_dataloaders(train_df, valid_df)

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cpu')

# %%
import csv
#print(df_train)



with open('/Users/albert/Documents/CSE8813_DLT/object_image2.csv') as csv_file:
    csv_reader = csv.reader(csv_file, delimiter=',')
    for row in csv_reader:
        ID = row[0]
        obj = row[1]
        
        str_obj = obj.replace("[","")
        str_obj = str_obj.replace("]","")
        train_df.loc[df_train["ID"] == int(row[0]),"object"] = str_obj

# %%
#print(df_train["object"])
print(train_df.isna().sum())
train_df = train_df.fillna(' ')
print(train_df["object"])
# Out:
# ID           0
# Text         0
# Sarcastic    0
# object       0
# dtype: int64
# 2                 'tvmonitor'
# 4              'zebra', 'cow'
# 5                     'train'
# 6
# 7
#                  ...
# 29034                'person'
# 29035
# 29036    'person', 'backpack'
# 29037                'person'
# 29039
# Name: object, Length: 19816, dtype: object

# %%
 text_train_dataloader,text_test_dataloader = prepare_dataloaders(train_df, test_df)
_,text_val_dataloader = prepare_dataloaders(train_df, valid_df)
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/envs/DLT_project2/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~/opt/anaconda3/envs/DLT_project2/lib/python3.8/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/opt/anaconda3/envs/DLT_project2/lib/python3.8/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'object'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /var/folders/6d/pg34ylzj4mn7fp70wgtbx64w0000gn/T/ipykernel_13207/3664342764.py in <module>
# ----> 1 text_train_dataloader,text_test_dataloader = prepare_dataloaders(train_df, test_df)
#       2 _,text_val_dataloader = prepare_dataloaders(train_df, valid_df)
#
# /var/folders/6d/pg34ylzj4mn7fp70wgtbx64w0000gn/T/ipykernel_13207/74299469.py in prepare_dataloaders(train_df, test_df, batch_size)
#       7     tokenizer = AutoTokenizer.from_pretrained("vinai/bertweet-base", use_fast=False, normalization=True)
#       8
# ----> 9     tweet_train = bert_encode(train_df, tokenizer)
#      10     tweet_train_labels = train_df['Sarcastic'].astype(int)
#      11
#
# /var/folders/6d/pg34ylzj4mn7fp70wgtbx64w0000gn/T/ipykernel_13207/2482649559.py in bert_encode(df, tokenizer)
#       3     attention_masks = []
#       4     # print(df)
# ----> 5     for sent,obj in zip(df[['Text']].values,df["object"].values):
#       6         sent = sent.item()
#       7         #print("sent")
#
# ~/opt/anaconda3/envs/DLT_project2/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3456             if self.columns.nlevels > 1:
#    3457                 return self._getitem_multilevel(key)
# -> 3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#    3460                 indexer = [indexer]
#
# ~/opt/anaconda3/envs/DLT_project2/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 'object'

# %%
def prepare_model(model_class="vinai/bertweet-base",num_classes=2,model_to_load=None,total_steps=-1):
    
    #model = AutoModel.from_pretrained(model_class)

    model = AutoModelForSequenceClassification.from_pretrained(
        model_class,
        num_labels = num_classes,  
        output_attentions = False, 
        output_hidden_states = True,
    )

    optimizer = AdamW(model.parameters(),
                    lr = 5e-5,
                    eps = 1e-8
                    )
    scheduler = get_linear_schedule_with_warmup(optimizer, 
                                                num_warmup_steps = 0, 
                                                num_training_steps = total_steps)

    if model_to_load is not None:
        try:
            model.roberta.load_state_dict(torch.load(model_to_load))
            print("LOADED MODEL")
        except:
            pass
    return model, optimizer, scheduler

# %%
count = 0
for batch in text_train_dataloader:
    count+=1
    print(batch[0])
    if count==5:
        break
# Out:
# tensor([[    0,   465, 18451,  ...,     1,     1,     1],
#         [    0,  8454,     9,  ...,     1,     1,     1],
#         [    0, 14249,  5163,  ...,     1,     1,     1],
#         ...,
#         [    0,   191,   213,  ...,     1,     1,     1],
#         [    0,    11, 14291,  ...,     1,     1,     1],
#         [    0,  8215,   288,  ...,     1,     1,     1]])
# tensor([[    0,     6, 11684,  ...,     1,     1,     1],
#         [    0, 16708,   465,  ...,     1,     1,     1],
#         [    0,   465, 43871,  ...,     1,     1,     1],
#         ...,
#         [    0,     6, 10426,  ...,     1,     1,     1],
#         [    0,    33,    17,  ...,     1,     1,     1],
#         [    0,     6,  5206,  ...,     1,     1,     1]])
# tensor([[   0, 1832,    6,  ...,    1,    1,    1],
#         [   0,   37,  863,  ...,    1,    1,    1],
#         [   0,    6, 1340,  ...,    1,    1,    1],
#         ...,
#         [   0,  618, 7186,  ...,    1,    1,    1],
#         [   0, 8454,    9,  ...,    1,    1,    1],
#         [   0,  225,  399,  ...,    1,    1,    1]])
# tensor([[    0,    13,   391,  ...,     1,     1,     1],
#         [    0,    64,    14,  ...,     1,     1,     1],
#         [    0,    33,    86,  ...,     1,     1,     1],
#         ...,
#         [    0,   465, 37089,  ...,     1,     1,     1],
#         [    0,    33,   152,  ...,     1,     1,     1],
#         [    0,   127,   437,  ...,     1,     1,     1]])
# tensor([[    0,  9646,   615,  ...,     1,     1,     1],
#         [    0, 32549,    17,  ...,     1,     1,     1],
#         [    0,   465,  3390,  ...,     1,     1,     1],
#         ...,
#         [    0,  5311,    35,  ...,     1,     1,     1],
#         [    0, 10584, 56843,  ...,     1,     1,     1],
#         [    0,  2958,   615,  ...,     1,     1,     1]])

# %%
class MultiModel(nn.Module):
    def __init__(self):
        super(MultiModel, self).__init__()
        #Resnet50 for image
        self.text_model, _, _ = prepare_model("vinai/bertweet-base" ,num_classes=2, model_to_load=None, total_steps = total_steps)
        self.linear_1 = nn.Linear(768,300)
        #self.text_model = AutoModelForSequenceClassification.from_pretrained(
        #model_class = "vinai/bertweet-base",
        #num_labels = 2,  
        #output_attentions = False, 
        #output_hidden_states = False,)
        
        self.image_model = torchvision.models.resnet50(
            pretrained=True
        )
        #resnet_output_feature_dim = 300
        #bert_output_feature_dim = 300
        #fusion_input_feature = 300+300 = 600
        self.image_model.fc = nn.Sequential(
               nn.Linear(2048, 128),
               nn.ReLU(inplace=True),
               nn.Linear(128, 300))
        
        
        # Combined
        
        #fusion_input_feature = 300+300 = 600
        #fusion_output_size = 128
        self.combined_fc1 = nn.Linear(600, 256)
        self.combined_fc2 = nn.Linear(256, 128)
        
        self.output_fc = nn.Linear(128, 2)
       
        #self.text_train_dataset = image_dataloaders["train"]
        #self.text_dev_dataset = image_dataloaders["validation"]
        #self.image_train_dataset = text_train_dataloader
        #self.image_dev_dataset = text_val_dataloader

    
    def forward(self, text,text_mask,image):
        text = text
        bert_out = self.text_model(text)
        #last_layer = bert_out.last_hidden_state[:,0,:]
        #last_layer = self.linear_1(last_layer)
        #print(len(bert_out))
        
        last_layer = bert_out.hidden_states[-1][:, 0, :]
        #print(last_layer.shape)
        image = image
        resnet_out = self.image_model(image)
        print("resnet output")
        print(resnet_out.shape)
        last_layer= self.linear_1(last_layer)
        combined_emb = torch.cat((resnet_out, last_layer), 1)
        print("combined_emb")
        print(combined_emb.shape)
        x_comb = F.relu(self.combined_fc1(combined_emb))
        x_comb = F.relu(self.combined_fc2(x_comb))
        out = torch.sigmoid(self.output_fc(x_comb))
        #logits = self.output_fc(x_comb)
        #pred = torch.nn.functional.softmax(logits)
        return out

# %%
#count = 0
#for batch, [image,label] in zip(text_train_dataloader,image_dataloaders["train"]):
#    count+=1
#    print("text input shape")
#    print(batch[0].shape)
#    print(batch[1].shape)
#    print(batch[2].shape)
#    print("image input shape")
#    print(image.shape)
#    print(label.shape)
#    if count==5:
#        break
# Out:
# text input shape
# torch.Size([64, 128])
# torch.Size([64, 128])
# torch.Size([64])
# image input shape
# torch.Size([64, 3, 224, 224])
# torch.Size([64])
# text input shape
# torch.Size([64, 128])
# torch.Size([64, 128])
# torch.Size([64])
# image input shape
# torch.Size([64, 3, 224, 224])
# torch.Size([64])
# text input shape
# torch.Size([64, 128])
# torch.Size([64, 128])
# torch.Size([64])
# image input shape
# torch.Size([64, 3, 224, 224])
# torch.Size([64])
# text input shape
# torch.Size([64, 128])
# torch.Size([64, 128])
# torch.Size([64])
# image input shape
# torch.Size([64, 3, 224, 224])
# torch.Size([64])
# text input shape
# torch.Size([64, 128])
# torch.Size([64, 128])
# torch.Size([64])
# image input shape
# torch.Size([64, 3, 224, 224])
# torch.Size([64])

# %%
def train_model(model, image_data_loaders,text_train_data_loader,text_val_data_loader, criterion, optimizer, num_epochs=3):
    for epoch in range(num_epochs):
        print('Epoch {}/{}'.format(epoch+1, num_epochs))
        print('-' * 10)

        for phase in ['train', 'validation']:
            if phase == 'train':
                model.train()
            else:
                model.eval()

            running_loss = 0.0
            running_corrects = 0

        
            for batch,[image_inputs,image_labels] in zip(text_train_data_loader,image_data_loaders[phase]):
                text_inputs = batch[0]
                text_mask = batch[1]
                text_labels = batch[2]
                text_inputs = text_inputs.to(device)
                text_labels = text_labels.to(device)
                image_inputs = image_inputs.to(device)
                image_labels = image_labels.to(device)
                outputs = model(text_inputs,text_mask,image_inputs)
                
                loss = criterion(outputs, image_labels)
                if phase == 'train':
                    optimizer.zero_grad()
                    loss.backward()
                    optimizer.step()

                _, preds = torch.max(outputs, 1)
                running_loss += loss.item() * image_inputs.size(0)
                running_corrects += torch.sum(preds == image_labels.data)

            epoch_loss = running_loss / len(image_datasets[phase])
            epoch_acc = running_corrects.double() / len(image_datasets[phase])

            print('{} loss: {:.4f}, acc: {:.4f}'.format(phase,
                                                        epoch_loss,
                                                        epoch_acc))
    return model

# %%
epochs = 10
total_steps = len(train_df) * epochs
model = MultiModel().to(device)

criterion = nn.CrossEntropyLoss()
optimizer = AdamW(model.parameters(),
                    lr = 5e-5,
                    eps = 1e-8
                    )

#loss_func = nn.MSELoss()
#optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/6d/pg34ylzj4mn7fp70wgtbx64w0000gn/T/ipykernel_13207/874537067.py in <module>
#       1 epochs = 10
#       2 total_steps = len(train_df) * epochs
# ----> 3 model = MultiModel().to(device)
#       4
#       5 criterion = nn.CrossEntropyLoss()
#
# /var/folders/6d/pg34ylzj4mn7fp70wgtbx64w0000gn/T/ipykernel_13207/1534939333.py in __init__(self)
#       3         super(MultiModel, self).__init__()
#       4         #Resnet50 for image
# ----> 5         self.text_model, _, _ = prepare_model("vinai/bertweet-base" ,num_classes=2, model_to_load=None, total_steps = total_steps)
#       6         self.linear_1 = nn.Linear(768,300)
#       7         #self.text_model = AutoModelForSequenceClassification.from_pretrained(
#
# NameError: name 'prepare_model' is not defined

# %%
model_trained = train_model(model,image_dataloaders,text_train_dataloader,text_val_dataloader, criterion, optimizer, num_epochs=10)
# Out:
# Epoch 1/10
# ----------

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)

# %%
torch.save(model, '/content/drive/MyDrive/Sarcasm-Detection-hierarchical_fusion_model/multimodal_10epoch.pt')
